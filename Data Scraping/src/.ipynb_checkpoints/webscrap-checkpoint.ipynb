# %% [markdown]
# # NBA Players Data Scraping

# %%
from bs4 import BeautifulSoup as soup
from selenium import webdriver
from selenium.webdriver.support.ui import Select

# %%
PATH = 'C:\Program Files (x86)\Google\Chrome\Application\chromedriver.exe'

driver = webdriver.Chrome(PATH)
url = 'https://www.nba.com/players'
driver.get(url)

# %%
#Select show 'all page' on HTML page

showPage_xpath = r'/html/body/div[1]/div[2]/div[3]/section/div/div[2]/div[1]/div[7]/div/div[3]/div/label/div/select'
showPage = Select(driver.find_element_by_xpath(showPage_xpath))

# %%
#Show all players data in table
showPage.select_by_index(0)

# %%
#Get HTML page source
page = driver.page_source

# %%
page_soup = soup(page, 'html.parser')

# %%
rows_container = page_soup.findAll('tr')

# %% [markdown]
# Get table rows from HTML page

# %%
rows_container.pop(0) # remove the table header
rows_container
# Out:
# [<tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1630173/precious-achiuwa/"><div class="w-8 h-8 mr-2"><img alt="Precious Achiuwa Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1630173.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Precious</p><p class="t6">Achiuwa</p></div></a></td><td class="text"><a class="t6" href="/team/1610612748/heat/">MIA</a></td><td>5</td><td class="text">F</td><td>6-8</td><td class="text">225<!-- --> <!-- -->lbs</td><td class="text">Memphis</td><td class="text">Nigeria</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1629121/jaylen-adams/"><div class="w-8 h-8 mr-2"><img alt="Jaylen Adams Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1629121.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Jaylen</p><p class="t6">Adams</p></div></a></td><td class="text"><p class="t2 t6"></p></td><td></td><td class="text">G</td><td>6-0</td><td class="text">225<!-- --> <!-- -->lbs</td><td class="text">St. Bonaventure</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/203500/steven-adams/"><div class="w-8 h-8 mr-2"><img alt="Steven Adams Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/203500.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Steven</p><p class="t6">Adams</p></div></a></td><td class="text"><a class="t6" href="/team/1610612740/pelicans/">NOP</a></td><td>12</td><td class="text">C</td><td>6-11</td><td class="text">265<!-- --> <!-- -->lbs</td><td class="text">Pittsburgh</td><td class="text">New Zealand</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1628389/bam-adebayo/"><div class="w-8 h-8 mr-2"><img alt="Bam Adebayo Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1628389.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Bam</p><p class="t6">Adebayo</p></div></a></td><td class="text"><a class="t6" href="/team/1610612748/heat/">MIA</a></td><td>13</td><td class="text">C-F</td><td>6-9</td><td class="text">255<!-- --> <!-- -->lbs</td><td class="text">Kentucky</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/200746/lamarcus-aldridge/"><div class="w-8 h-8 mr-2"><img alt="LaMarcus Aldridge Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/200746.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">LaMarcus</p><p class="t6">Aldridge</p></div></a></td><td class="text"><p class="t2 t6"></p></td><td></td><td class="text">C-F</td><td>6-11</td><td class="text">250<!-- --> <!-- -->lbs</td><td class="text">Texas-Austin</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1630234/ty-shon-alexander/"><div class="w-8 h-8 mr-2"><img alt="Ty-Shon Alexander Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1630234.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Ty-Shon</p><p class="t6">Alexander</p></div></a></td><td class="text"><a class="t6" href="/team/1610612756/suns/">PHX</a></td><td>0</td><td class="text">G</td><td>6-3</td><td class="text">195<!-- --> <!-- -->lbs</td><td class="text">Creighton</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1629638/nickeil-alexander-walker/"><div class="w-8 h-8 mr-2"><img alt="Nickeil Alexander-Walker Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1629638.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Nickeil</p><p class="t6">Alexander-Walker</p></div></a></td><td class="text"><a class="t6" href="/team/1610612740/pelicans/">NOP</a></td><td>6</td><td class="text">G</td><td>6-6</td><td class="text">205<!-- --> <!-- -->lbs</td><td class="text">Virginia Tech</td><td class="text">Canada</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1628960/grayson-allen/"><div class="w-8 h-8 mr-2"><img alt="Grayson Allen Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1628960.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Grayson</p><p class="t6">Allen</p></div></a></td><td class="text"><a class="t6" href="/team/1610612763/grizzlies/">MEM</a></td><td>3</td><td class="text">G</td><td>6-4</td><td class="text">198<!-- --> <!-- -->lbs</td><td class="text">Duke</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1628386/jarrett-allen/"><div class="w-8 h-8 mr-2"><img alt="Jarrett Allen Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1628386.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Jarrett</p><p class="t6">Allen</p></div></a></td><td class="text"><a class="t6" href="/team/1610612739/cavaliers/">CLE</a></td><td>31</td><td class="text">C</td><td>6-11</td><td class="text">243<!-- --> <!-- -->lbs</td><td class="text">Texas-Austin</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/202329/al-farouq-aminu/"><div class="w-8 h-8 mr-2"><img alt="Al-Farouq Aminu Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/202329.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Al-Farouq</p><p class="t6">Aminu</p></div></a></td><td class="text"><a class="t6" href="/team/1610612741/bulls/">CHI</a></td><td>5</td><td class="text">F</td><td>6-8</td><td class="text">220<!-- --> <!-- -->lbs</td><td class="text">Wake Forest</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/203937/kyle-anderson/"><div class="w-8 h-8 mr-2"><img alt="Kyle Anderson Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/203937.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Kyle</p><p class="t6">Anderson</p></div></a></td><td class="text"><a class="t6" href="/team/1610612763/grizzlies/">MEM</a></td><td>1</td><td class="text">F-G</td><td>6-9</td><td class="text">230<!-- --> <!-- -->lbs</td><td class="text">UCLA</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/203507/giannis-antetokounmpo/"><div class="w-8 h-8 mr-2"><img alt="Giannis Antetokounmpo Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/203507.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Giannis</p><p class="t6">Antetokounmpo</p></div></a></td><td class="text"><a class="t6" href="/team/1610612749/bucks/">MIL</a></td><td>34</td><td class="text">F</td><td>6-11</td><td class="text">242<!-- --> <!-- -->lbs</td><td class="text">Filathlitikos</td><td class="text">Greece</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1628961/kostas-antetokounmpo/"><div class="w-8 h-8 mr-2"><img alt="Kostas Antetokounmpo Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1628961.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Kostas</p><p class="t6">Antetokounmpo</p></div></a></td><td class="text"><a class="t6" href="/team/1610612747/lakers/">LAL</a></td><td>37</td><td class="text">F</td><td>6-10</td><td class="text">200<!-- --> <!-- -->lbs</td><td class="text">Dayton</td><td class="text">Greece</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/203648/thanasis-antetokounmpo/"><div class="w-8 h-8 mr-2"><img alt="Thanasis Antetokounmpo Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/203648.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Thanasis</p><p class="t6">Antetokounmpo</p></div></a></td><td class="text"><a class="t6" href="/team/1610612749/bucks/">MIL</a></td><td>43</td><td class="text">F</td><td>6-6</td><td class="text">219<!-- --> <!-- -->lbs</td><td class="text">Panathinaikos</td><td class="text">Greece</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/2546/carmelo-anthony/"><div class="w-8 h-8 mr-2"><img alt="Carmelo Anthony Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/2546.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Carmelo</p><p class="t6">Anthony</p></div></a></td><td class="text"><a class="t6" href="/team/1610612757/blazers/">POR</a></td><td>00</td><td class="text">F</td><td>6-7</td><td class="text">238<!-- --> <!-- -->lbs</td><td class="text">Syracuse</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1630175/cole-anthony/"><div class="w-8 h-8 mr-2"><img alt="Cole Anthony Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1630175.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Cole</p><p class="t6">Anthony</p></div></a></td><td class="text"><a class="t6" href="/team/1610612753/magic/">ORL</a></td><td>50</td><td class="text">G</td><td>6-2</td><td class="text">185<!-- --> <!-- -->lbs</td><td class="text">North Carolina</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1628384/og-anunoby/"><div class="w-8 h-8 mr-2"><img alt="OG Anunoby Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1628384.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">OG</p><p class="t6">Anunoby</p></div></a></td><td class="text"><a class="t6" href="/team/1610612761/raptors/">TOR</a></td><td>3</td><td class="text">F</td><td>6-7</td><td class="text">232<!-- --> <!-- -->lbs</td><td class="text">Indiana</td><td class="text">United Kingdom</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1627853/ryan-arcidiacono/"><div class="w-8 h-8 mr-2"><img alt="Ryan Arcidiacono Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1627853.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Ryan</p><p class="t6">Arcidiacono</p></div></a></td><td class="text"><a class="t6" href="/team/1610612741/bulls/">CHI</a></td><td>51</td><td class="text">G</td><td>6-3</td><td class="text">195<!-- --> <!-- -->lbs</td><td class="text">Villanova</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/2772/trevor-ariza/"><div class="w-8 h-8 mr-2"><img alt="Trevor Ariza Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/2772.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Trevor</p><p class="t6">Ariza</p></div></a></td><td class="text"><a class="t6" href="/team/1610612748/heat/">MIA</a></td><td>8</td><td class="text">F</td><td>6-8</td><td class="text">215<!-- --> <!-- -->lbs</td><td class="text">UCLA</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/201571/dj-augustin/"><div class="w-8 h-8 mr-2"><img alt="D.J. Augustin Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/201571.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">D.J.</p><p class="t6">Augustin</p></div></a></td><td class="text"><a class="t6" href="/team/1610612745/rockets/">HOU</a></td><td>14</td><td class="text">G</td><td>5-11</td><td class="text">183<!-- --> <!-- -->lbs</td><td class="text">Texas-Austin</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1630166/deni-avdija/"><div class="w-8 h-8 mr-2"><img alt="Deni Avdija Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1630166.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Deni</p><p class="t6">Avdija</p></div></a></td><td class="text"><a class="t6" href="/team/1610612764/wizards/">WAS</a></td><td>9</td><td class="text">F</td><td>6-9</td><td class="text">210<!-- --> <!-- -->lbs</td><td class="text">Maccabi Tel Aviv</td><td class="text">Israel</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1629028/deandre-ayton/"><div class="w-8 h-8 mr-2"><img alt="Deandre Ayton Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1629028.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Deandre</p><p class="t6">Ayton</p></div></a></td><td class="text"><a class="t6" href="/team/1610612756/suns/">PHX</a></td><td>22</td><td class="text">C</td><td>6-11</td><td class="text">250<!-- --> <!-- -->lbs</td><td class="text">Arizona</td><td class="text">Bahamas</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1628962/udoka-azubuike/"><div class="w-8 h-8 mr-2"><img alt="Udoka Azubuike Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1628962.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Udoka</p><p class="t6">Azubuike</p></div></a></td><td class="text"><a class="t6" href="/team/1610612762/jazz/">UTA</a></td><td>20</td><td class="text">C-F</td><td>6-10</td><td class="text">280<!-- --> <!-- -->lbs</td><td class="text">Kansas</td><td class="text">Nigeria</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1628407/dwayne-bacon/"><div class="w-8 h-8 mr-2"><img alt="Dwayne Bacon Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1628407.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Dwayne</p><p class="t6">Bacon</p></div></a></td><td class="text"><a class="t6" href="/team/1610612753/magic/">ORL</a></td><td>8</td><td class="text">G-F</td><td>6-6</td><td class="text">221<!-- --> <!-- -->lbs</td><td class="text">Florida State</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1628963/marvin-bagley-iii/"><div class="w-8 h-8 mr-2"><img alt="Marvin Bagley III Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1628963.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Marvin</p><p class="t6">Bagley III</p></div></a></td><td class="text"><a class="t6" href="/team/1610612758/kings/">SAC</a></td><td>35</td><td class="text">F</td><td>6-11</td><td class="text">235<!-- --> <!-- -->lbs</td><td class="text">Duke</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1630163/lamelo-ball/"><div class="w-8 h-8 mr-2"><img alt="LaMelo Ball Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1630163.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">LaMelo</p><p class="t6">Ball</p></div></a></td><td class="text"><a class="t6" href="/team/1610612766/hornets/">CHA</a></td><td>2</td><td class="text">G</td><td>6-6</td><td class="text">180<!-- --> <!-- -->lbs</td><td class="text">Illawarra</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1628366/lonzo-ball/"><div class="w-8 h-8 mr-2"><img alt="Lonzo Ball Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1628366.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Lonzo</p><p class="t6">Ball</p></div></a></td><td class="text"><a class="t6" href="/team/1610612740/pelicans/">NOP</a></td><td>2</td><td class="text">G</td><td>6-6</td><td class="text">190<!-- --> <!-- -->lbs</td><td class="text">UCLA</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1628964/mo-bamba/"><div class="w-8 h-8 mr-2"><img alt="Mo Bamba Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1628964.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Mo</p><p class="t6">Bamba</p></div></a></td><td class="text"><a class="t6" href="/team/1610612753/magic/">ORL</a></td><td>5</td><td class="text">C</td><td>7-0</td><td class="text">231<!-- --> <!-- -->lbs</td><td class="text">Texas-Austin</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1630217/desmond-bane/"><div class="w-8 h-8 mr-2"><img alt="Desmond Bane Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1630217.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Desmond</p><p class="t6">Bane</p></div></a></td><td class="text"><a class="t6" href="/team/1610612763/grizzlies/">MEM</a></td><td>22</td><td class="text">G</td><td>6-5</td><td class="text">215<!-- --> <!-- -->lbs</td><td class="text">TCU</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/203084/harrison-barnes/"><div class="w-8 h-8 mr-2"><img alt="Harrison Barnes Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/203084.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Harrison</p><p class="t6">Barnes</p></div></a></td><td class="text"><a class="t6" href="/team/1610612758/kings/">SAC</a></td><td>40</td><td class="text">F</td><td>6-8</td><td class="text">225<!-- --> <!-- -->lbs</td><td class="text">North Carolina</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1629628/rj-barrett/"><div class="w-8 h-8 mr-2"><img alt="RJ Barrett Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1629628.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">RJ</p><p class="t6">Barrett</p></div></a></td><td class="text"><a class="t6" href="/team/1610612752/knicks/">NYK</a></td><td>9</td><td class="text">F-G</td><td>6-6</td><td class="text">214<!-- --> <!-- -->lbs</td><td class="text">Duke</td><td class="text">Canada</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/203115/will-barton/"><div class="w-8 h-8 mr-2"><img alt="Will Barton Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/203115.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Will</p><p class="t6">Barton</p></div></a></td><td class="text"><a class="t6" href="/team/1610612743/nuggets/">DEN</a></td><td>5</td><td class="text">G</td><td>6-6</td><td class="text">181<!-- --> <!-- -->lbs</td><td class="text">Memphis</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1628966/keita-bates-diop/"><div class="w-8 h-8 mr-2"><img alt="Keita Bates-Diop Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1628966.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Keita</p><p class="t6">Bates-Diop</p></div></a></td><td class="text"><a class="t6" href="/team/1610612759/spurs/">SAS</a></td><td>31</td><td class="text">F</td><td>6-8</td><td class="text">229<!-- --> <!-- -->lbs</td><td class="text">Ohio State</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/201587/nicolas-batum/"><div class="w-8 h-8 mr-2"><img alt="Nicolas Batum Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/201587.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Nicolas</p><p class="t6">Batum</p></div></a></td><td class="text"><a class="t6" href="/team/1610612746/clippers/">LAC</a></td><td>33</td><td class="text">G-F</td><td>6-8</td><td class="text">230<!-- --> <!-- -->lbs</td><td class="text">Le Mans</td><td class="text">France</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/203382/aron-baynes/"><div class="w-8 h-8 mr-2"><img alt="Aron Baynes Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/203382.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Aron</p><p class="t6">Baynes</p></div></a></td><td class="text"><a class="t6" href="/team/1610612761/raptors/">TOR</a></td><td>46</td><td class="text">C-F</td><td>6-10</td><td class="text">260<!-- --> <!-- -->lbs</td><td class="text">Washington State</td><td class="text">Australia</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/203145/kent-bazemore/"><div class="w-8 h-8 mr-2"><img alt="Kent Bazemore Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/203145.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Kent</p><p class="t6">Bazemore</p></div></a></td><td class="text"><a class="t6" href="/team/1610612744/warriors/">GSW</a></td><td>26</td><td class="text">G-F</td><td>6-4</td><td class="text">195<!-- --> <!-- -->lbs</td><td class="text">Old Dominion</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1629647/darius-bazley/"><div class="w-8 h-8 mr-2"><img alt="Darius Bazley Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1629647.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Darius</p><p class="t6">Bazley</p></div></a></td><td class="text"><a class="t6" href="/team/1610612760/thunder/">OKC</a></td><td>7</td><td class="text">F-G</td><td>6-8</td><td class="text">208<!-- --> <!-- -->lbs</td><td class="text">Princeton HS (OH)</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/203078/bradley-beal/"><div class="w-8 h-8 mr-2"><img alt="Bradley Beal Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/203078.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Bradley</p><p class="t6">Beal</p></div></a></td><td class="text"><a class="t6" href="/team/1610612764/wizards/">WAS</a></td><td>3</td><td class="text">G</td><td>6-3</td><td class="text">207<!-- --> <!-- -->lbs</td><td class="text">Florida</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1627736/malik-beasley/"><div class="w-8 h-8 mr-2"><img alt="Malik Beasley Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1627736.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Malik</p><p class="t6">Beasley</p></div></a></td><td class="text"><a class="t6" href="/team/1610612750/timberwolves/">MIN</a></td><td>5</td><td class="text">G</td><td>6-4</td><td class="text">187<!-- --> <!-- -->lbs</td><td class="text">Florida State</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1628395/jordan-bell/"><div class="w-8 h-8 mr-2"><img alt="Jordan Bell Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1628395.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Jordan</p><p class="t6">Bell</p></div></a></td><td class="text"><a class="t6" href="/team/1610612744/warriors/">GSW</a></td><td>7</td><td class="text">F</td><td>6-8</td><td class="text">216<!-- --> <!-- -->lbs</td><td class="text">Oregon</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1627761/deandre-bembry/"><div class="w-8 h-8 mr-2"><img alt="DeAndre' Bembry Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1627761.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">DeAndre'</p><p class="t6">Bembry</p></div></a></td><td class="text"><a class="t6" href="/team/1610612761/raptors/">TOR</a></td><td>95</td><td class="text">G-F</td><td>6-5</td><td class="text">210<!-- --> <!-- -->lbs</td><td class="text">St. Joseph's (PA)</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/202722/davis-bertans/"><div class="w-8 h-8 mr-2"><img alt="Davis Bertans Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/202722.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Davis</p><p class="t6">Bertans</p></div></a></td><td class="text"><a class="t6" href="/team/1610612764/wizards/">WAS</a></td><td>42</td><td class="text">F</td><td>6-10</td><td class="text">225<!-- --> <!-- -->lbs</td><td class="text">Baskonia</td><td class="text">Latvia</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/201976/patrick-beverley/"><div class="w-8 h-8 mr-2"><img alt="Patrick Beverley Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/201976.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Patrick</p><p class="t6">Beverley</p></div></a></td><td class="text"><a class="t6" href="/team/1610612746/clippers/">LAC</a></td><td>21</td><td class="text">G</td><td>6-1</td><td class="text">180<!-- --> <!-- -->lbs</td><td class="text">Arkansas</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1630180/saddiq-bey/"><div class="w-8 h-8 mr-2"><img alt="Saddiq Bey Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1630180.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Saddiq</p><p class="t6">Bey</p></div></a></td><td class="text"><a class="t6" href="/team/1610612765/pistons/">DET</a></td><td>41</td><td class="text">F</td><td>6-7</td><td class="text">215<!-- --> <!-- -->lbs</td><td class="text">Villanova</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1630189/tyler-bey/"><div class="w-8 h-8 mr-2"><img alt="Tyler Bey Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1630189.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Tyler</p><p class="t6">Bey</p></div></a></td><td class="text"><a class="t6" href="/team/1610612742/mavericks/">DAL</a></td><td>2</td><td class="text">F</td><td>6-7</td><td class="text">215<!-- --> <!-- -->lbs</td><td class="text">Colorado</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/203920/khem-birch/"><div class="w-8 h-8 mr-2"><img alt="Khem Birch Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/203920.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Khem</p><p class="t6">Birch</p></div></a></td><td class="text"><a class="t6" href="/team/1610612761/raptors/">TOR</a></td><td>24</td><td class="text">C</td><td>6-9</td><td class="text">233<!-- --> <!-- -->lbs</td><td class="text">UNLV</td><td class="text">Canada</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/1629048/goga-bitadze/"><div class="w-8 h-8 mr-2"><img alt="Goga Bitadze Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1629048.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Goga</p><p class="t6">Bitadze</p></div></a></td><td class="text"><a class="t6" href="/team/1610612754/pacers/">IND</a></td><td>88</td><td class="text">C-F</td><td>6-11</td><td class="text">250<!-- --> <!-- -->lbs</td><td class="text">Mega Basket</td><td class="text">Georgia</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/202687/bismack-biyombo/"><div class="w-8 h-8 mr-2"><img alt="Bismack Biyombo Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/202687.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Bismack</p><p class="t6">Biyombo</p></div></a></td><td class="text"><a class="t6" href="/team/1610612766/hornets/">CHA</a></td><td>8</td><td class="text">C</td><td>6-8</td><td class="text">255<!-- --> <!-- -->lbs</td><td class="text">Baloncesto Fuenlabrada</td><td class="text">DRC</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/202357/nemanja-bjelica/"><div class="w-8 h-8 mr-2"><img alt="Nemanja Bjelica Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/202357.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Nemanja</p><p class="t6">Bjelica</p></div></a></td><td class="text"><a class="t6" href="/team/1610612748/heat/">MIA</a></td><td>70</td><td class="text">F</td><td>6-10</td><td class="text">234<!-- --> <!-- -->lbs</td><td class="text">Fenerbahce</td><td class="text">Serbia</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="/player/202339/eric-bledsoe/"><div class="w-8 h-8 mr-2"><img alt="Eric Bledsoe Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/202339.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Eric</p><p class="t6">Bledsoe</p></div></a></td><td class="text"><a class="t6" href="/team/1610612740/pelicans/">NOP</a></td><td>5</td><td class="text">G</td><td>6-1</td><td class="text">214<!-- --> <!-- -->lbs</td><td class="text">Kentucky</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1629833/keljin-blevins/"><div class="w-8 h-8 mr-2"><img alt="Keljin Blevins Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1629833.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Keljin</p><p class="t6">Blevins</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612757/blazers/">POR</a></td><td>21</td><td class="text">G</td><td>6-4</td><td class="text">200 lbs</td><td class="text">Montana State</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/203992/bogdan-bogdanovic/"><div class="w-8 h-8 mr-2"><img alt="Bogdan Bogdanovic Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/203992.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Bogdan</p><p class="t6">Bogdanovic</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612737/hawks/">ATL</a></td><td>13</td><td class="text">G</td><td>6-6</td><td class="text">220 lbs</td><td class="text">Fenerbahce</td><td class="text">Serbia</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/202711/bojan-bogdanovic/"><div class="w-8 h-8 mr-2"><img alt="Bojan Bogdanovic Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/202711.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Bojan</p><p class="t6">Bogdanovic</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612762/jazz/">UTA</a></td><td>44</td><td class="text">F</td><td>6-7</td><td class="text">226 lbs</td><td class="text">Fenerbahce</td><td class="text">Croatia</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1629626/bol-bol/"><div class="w-8 h-8 mr-2"><img alt="Bol Bol Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1629626.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Bol</p><p class="t6">Bol</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612743/nuggets/">DEN</a></td><td>10</td><td class="text">C-F</td><td>7-2</td><td class="text">220 lbs</td><td class="text">Oregon</td><td class="text">Sudan</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1629716/marques-bolden/"><div class="w-8 h-8 mr-2"><img alt="Marques Bolden Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1629716.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Marques</p><p class="t6">Bolden</p></div></a></td><td class="text"><p class="t2 t6"></p></td><td></td><td class="text">C</td><td>6-10</td><td class="text">249 lbs</td><td class="text">Duke</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1629648/jordan-bone/"><div class="w-8 h-8 mr-2"><img alt="Jordan Bone Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1629648.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Jordan</p><p class="t6">Bone</p></div></a></td><td class="text"><p class="t2 t6"></p></td><td></td><td class="text">G</td><td>6-2</td><td class="text">180 lbs</td><td class="text">Tennessee</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1629067/isaac-bonga/"><div class="w-8 h-8 mr-2"><img alt="Isaac Bonga Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1629067.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Isaac</p><p class="t6">Bonga</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612764/wizards/">WAS</a></td><td>17</td><td class="text">G</td><td>6-8</td><td class="text">180 lbs</td><td class="text">Skyliners Frankfurt</td><td class="text">Germany</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1626164/devin-booker/"><div class="w-8 h-8 mr-2"><img alt="Devin Booker Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1626164.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Devin</p><p class="t6">Booker</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612756/suns/">PHX</a></td><td>1</td><td class="text">G</td><td>6-5</td><td class="text">206 lbs</td><td class="text">Kentucky</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1628449/chris-boucher/"><div class="w-8 h-8 mr-2"><img alt="Chris Boucher Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1628449.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Chris</p><p class="t6">Boucher</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612761/raptors/">TOR</a></td><td>25</td><td class="text">F-C</td><td>6-9</td><td class="text">200 lbs</td><td class="text">Oregon</td><td class="text">Saint Lucia</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1628968/brian-bowen-ii/"><div class="w-8 h-8 mr-2"><img alt="Brian Bowen II Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1628968.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Brian</p><p class="t6">Bowen II</p></div></a></td><td class="text"><p class="t2 t6"></p></td><td></td><td class="text">F-G</td><td>6-6</td><td class="text">190 lbs</td><td class="text"> </td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/202340/avery-bradley/"><div class="w-8 h-8 mr-2"><img alt="Avery Bradley Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/202340.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Avery</p><p class="t6">Bradley</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612745/rockets/">HOU</a></td><td>9</td><td class="text">G</td><td>6-3</td><td class="text">180 lbs</td><td class="text">Texas-Austin</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1628396/tony-bradley/"><div class="w-8 h-8 mr-2"><img alt="Tony Bradley Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1628396.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Tony</p><p class="t6">Bradley</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612760/thunder/">OKC</a></td><td>13</td><td class="text">C-F</td><td>6-10</td><td class="text">248 lbs</td><td class="text">North Carolina</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1629714/jarrell-brantley/"><div class="w-8 h-8 mr-2"><img alt="Jarrell Brantley Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1629714.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Jarrell</p><p class="t6">Brantley</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612762/jazz/">UTA</a></td><td>5</td><td class="text">F</td><td>6-5</td><td class="text">250 lbs</td><td class="text">College of Charleston</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1629649/ignas-brazdeikis/"><div class="w-8 h-8 mr-2"><img alt="Ignas Brazdeikis Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1629649.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Ignas</p><p class="t6">Brazdeikis</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612753/magic/">ORL</a></td><td>17</td><td class="text">F</td><td>6-6</td><td class="text">221 lbs</td><td class="text">Michigan</td><td class="text">Canada</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1628969/mikal-bridges/"><div class="w-8 h-8 mr-2"><img alt="Mikal Bridges Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1628969.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Mikal</p><p class="t6">Bridges</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612756/suns/">PHX</a></td><td>25</td><td class="text">F</td><td>6-6</td><td class="text">209 lbs</td><td class="text">Villanova</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1628970/miles-bridges/"><div class="w-8 h-8 mr-2"><img alt="Miles Bridges Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1628970.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Miles</p><p class="t6">Bridges</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612766/hornets/">CHA</a></td><td>0</td><td class="text">F</td><td>6-6</td><td class="text">225 lbs</td><td class="text">Michigan State</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1628578/amida-brimah/"><div class="w-8 h-8 mr-2"><img alt="Amida Brimah Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1628578.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Amida</p><p class="t6">Brimah</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612754/pacers/">IND</a></td><td>37</td><td class="text">C</td><td>6-10</td><td class="text">230 lbs</td><td class="text">Connecticut</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1629052/oshae-brissett/"><div class="w-8 h-8 mr-2"><img alt="Oshae Brissett Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1629052.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Oshae</p><p class="t6">Brissett</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612754/pacers/">IND</a></td><td>12</td><td class="text">F-G</td><td>6-7</td><td class="text">210 lbs</td><td class="text">Syracuse</td><td class="text">Canada</td></tr>,
# ...
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/202355/hassan-whiteside/"><div class="w-8 h-8 mr-2"><img alt="Hassan Whiteside Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/202355.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Hassan</p><p class="t6">Whiteside</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612758/kings/">SAC</a></td><td>20</td><td class="text">C</td><td>7-0</td><td class="text">265 lbs</td><td class="text">Marshall</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/204222/greg-whittington/"><div class="w-8 h-8 mr-2"><img alt="Greg Whittington Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/204222.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Greg</p><p class="t6">Whittington</p></div></a></td><td class="text"><p class="t2 t6"></p></td><td></td><td class="text">F</td><td>6-8</td><td class="text">210 lbs</td><td class="text">Georgetown</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/203952/andrew-wiggins/"><div class="w-8 h-8 mr-2"><img alt="Andrew Wiggins Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/203952.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Andrew</p><p class="t6">Wiggins</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612744/warriors/">GSW</a></td><td>22</td><td class="text">F</td><td>6-7</td><td class="text">197 lbs</td><td class="text">Kansas</td><td class="text">Canada</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1629684/grant-williams/"><div class="w-8 h-8 mr-2"><img alt="Grant Williams Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1629684.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Grant</p><p class="t6">Williams</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612738/celtics/">BOS</a></td><td>12</td><td class="text">F</td><td>6-6</td><td class="text">236 lbs</td><td class="text">Tennessee</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1629026/kenrich-williams/"><div class="w-8 h-8 mr-2"><img alt="Kenrich Williams Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1629026.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Kenrich</p><p class="t6">Williams</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612760/thunder/">OKC</a></td><td>34</td><td class="text">G-F</td><td>6-6</td><td class="text">210 lbs</td><td class="text">TCU</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/101150/lou-williams/"><div class="w-8 h-8 mr-2"><img alt="Lou Williams Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/101150.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Lou</p><p class="t6">Williams</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612737/hawks/">ATL</a></td><td>6</td><td class="text">G</td><td>6-1</td><td class="text">175 lbs</td><td class="text">South Gwinnett HS (GA)</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1630172/patrick-williams/"><div class="w-8 h-8 mr-2"><img alt="Patrick Williams Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1630172.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Patrick</p><p class="t6">Williams</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612741/bulls/">CHI</a></td><td>44</td><td class="text">F</td><td>6-7</td><td class="text">215 lbs</td><td class="text">Florida State</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1629057/robert-williams-iii/"><div class="w-8 h-8 mr-2"><img alt="Robert Williams III Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1629057.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Robert</p><p class="t6">Williams III</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612738/celtics/">BOS</a></td><td>44</td><td class="text">C-F</td><td>6-8</td><td class="text">237 lbs</td><td class="text">Texas A&amp;M</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1629627/zion-williamson/"><div class="w-8 h-8 mr-2"><img alt="Zion Williamson Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1629627.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Zion</p><p class="t6">Williamson</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612740/pelicans/">NOP</a></td><td>1</td><td class="text">F</td><td>6-7</td><td class="text">284 lbs</td><td class="text">Duke</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1628391/dj-wilson/"><div class="w-8 h-8 mr-2"><img alt="D.J. Wilson Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1628391.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">D.J.</p><p class="t6">Wilson</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612745/rockets/">HOU</a></td><td>00</td><td class="text">F</td><td>6-10</td><td class="text">231 lbs</td><td class="text">Michigan</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1629685/dylan-windler/"><div class="w-8 h-8 mr-2"><img alt="Dylan Windler Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1629685.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Dylan</p><p class="t6">Windler</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612739/cavaliers/">CLE</a></td><td>9</td><td class="text">G-F</td><td>6-6</td><td class="text">196 lbs</td><td class="text">Belmont</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1626159/justise-winslow/"><div class="w-8 h-8 mr-2"><img alt="Justise Winslow Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1626159.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Justise</p><p class="t6">Winslow</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612763/grizzlies/">MEM</a></td><td>7</td><td class="text">F-G</td><td>6-6</td><td class="text">222 lbs</td><td class="text">Duke</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1630216/cassius-winston/"><div class="w-8 h-8 mr-2"><img alt="Cassius Winston Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1630216.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Cassius</p><p class="t6">Winston</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612764/wizards/">WAS</a></td><td>5</td><td class="text">G</td><td>6-1</td><td class="text">185 lbs</td><td class="text">Michigan State</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1630164/james-wiseman/"><div class="w-8 h-8 mr-2"><img alt="James Wiseman Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1630164.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">James</p><p class="t6">Wiseman</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612744/warriors/">GSW</a></td><td>33</td><td class="text">C</td><td>7-0</td><td class="text">240 lbs</td><td class="text">Memphis</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1626174/christian-wood/"><div class="w-8 h-8 mr-2"><img alt="Christian Wood Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1626174.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Christian</p><p class="t6">Wood</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612745/rockets/">HOU</a></td><td>35</td><td class="text">F</td><td>6-10</td><td class="text">214 lbs</td><td class="text">UNLV</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1630218/robert-woodard-ii/"><div class="w-8 h-8 mr-2"><img alt="Robert Woodard II Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1630218.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Robert</p><p class="t6">Woodard II</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612758/kings/">SAC</a></td><td>13</td><td class="text">F</td><td>6-6</td><td class="text">235 lbs</td><td class="text">Mississippi State</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1626153/delon-wright/"><div class="w-8 h-8 mr-2"><img alt="Delon Wright Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1626153.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Delon</p><p class="t6">Wright</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612758/kings/">SAC</a></td><td>55</td><td class="text">G</td><td>6-5</td><td class="text">185 lbs</td><td class="text">Utah</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/201152/thaddeus-young/"><div class="w-8 h-8 mr-2"><img alt="Thaddeus Young Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/201152.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Thaddeus</p><p class="t6">Young</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612741/bulls/">CHI</a></td><td>21</td><td class="text">F</td><td>6-8</td><td class="text">235 lbs</td><td class="text">Georgia Tech</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1629027/trae-young/"><div class="w-8 h-8 mr-2"><img alt="Trae Young Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1629027.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Trae</p><p class="t6">Young</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612737/hawks/">ATL</a></td><td>11</td><td class="text">G</td><td>6-1</td><td class="text">180 lbs</td><td class="text">Oklahoma</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1630209/omer-yurtseven/"><div class="w-8 h-8 mr-2"><img alt="Omer Yurtseven Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1630209.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Omer</p><p class="t6">Yurtseven</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612748/heat/">MIA</a></td><td>77</td><td class="text">C</td><td>7-0</td><td class="text">275 lbs</td><td class="text">Georgetown</td><td class="text">Uzbekistan</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/203469/cody-zeller/"><div class="w-8 h-8 mr-2"><img alt="Cody Zeller Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/203469.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Cody</p><p class="t6">Zeller</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612766/hornets/">CHA</a></td><td>40</td><td class="text">F-C</td><td>6-11</td><td class="text">240 lbs</td><td class="text">Indiana</td><td class="text">USA</td></tr>,
#  <tr><td class="primary text RosterRow_primaryCol__19xPQ"><a class="flex items-center t6 Anchor_complexLink__2NtkO" href="https://www.nba.com/player/1627826/ivica-zubac/"><div class="w-8 h-8 mr-2"><img alt="Ivica Zubac Headshot" class="PlayerImage_image__1smob PlayerImage_round__281uY" loading="lazy" src="https://cdn.nba.com/headshots/nba/latest/260x190/1627826.png"/></div><div class="flex flex-col lg:flex-row"><p class="t6 mr-1">Ivica</p><p class="t6">Zubac</p></div></a></td><td class="text"><a class="t6" href="https://www.nba.com/team/1610612746/clippers/">LAC</a></td><td>40</td><td class="text">C</td><td>7-0</td><td class="text">240 lbs</td><td class="text">Mega Basket</td><td class="text">Croatia</td></tr>]

# %% [markdown]
# Data transformation

# %%
#Dictionary to translate initial team name to full team name


team_dict = {
    'PHI' : 'Philadelphia 76ers',
    'MIL' : 'Milwaukee Bucks',
    'CHI' : 'Chicago Bulls',
    'CLE' : 'Cleveland Cavaliers',
    'BOS' : 'Boston Celtics',
    'LAC' : 'LA Clippers',
    'MEM' : 'Memphis Grizzlies',
    'ATL' : 'Atlanta Hawks',
    'MIA' : 'Miami Heat',
    'CHA' : 'Charlotte Hornets',
    'UTA' : 'Utah Jazz',
    'SAC' : 'Sacramento Kings',
    'NYK' : 'New York Knicks',
    'LAL' : 'Los Angeles Lakers',
    'ORL' : 'Orlando Magic',
    'DAL' : 'Dallas Mavericks',
    'BKN' : 'Brooklyn Nets',
    'DEN' : 'Denver Nuggets',
    'IND' : 'Indiana Pacers',
    'NOP' : 'New Orleans Pelicans',
    'DET' : 'Detroit Pistons',
    'TOR' : 'Toronto Raptors',
    'HOU' : 'Houston Rockets',
    'SAS' : 'San Antonio Spurs',
    'PHX' : 'Phoenix Suns',
    'OKC' : 'Oklahoma Thunder',
    'MIN' : 'Minnesota Timberwolves',
    'POR' : 'Portland Trail Blazers',
    'GSW' : 'Golden State Wariors',
    'WAS' : 'Washington Wizards'
}

#for transforming weight data from string to float
def transformPlayersHeightData(heightString) :
    #transform heightString. ex: '6-10'(string) to 6.10 (float)
    height = float(heightString.replace('-', '.'))
    #convert foot to cm
    return round(height*30.48, 1)

#for transforming weight data from string to int
def transformPlayersWeightData(weightSring) :
    #transform weightString. ex '255 lbs'(string) to 255 (int)
    weight = int(weightSring.replace(' lbs', ''))
    
    #convert pound to kg
    return int(weight/2.205)

# %% [markdown]
# Scraping

# %%
players_container = {} #to store all players data

for data in rows_container :
    #get name
    first_name = data.findAll('p')[0].text
    last_name = data.findAll('p')[1].text
    full_name = first_name + ' ' + last_name
    
    #get team
    try :
        team_initial = data.findAll('a', {'class' : 't6'})[1].text
        team = team_dict[team_initial]
    except :
        team = None
    
    #get number
    try :
        number = int(data.findAll('td')[2].text)
    except :
        number = None
    
    #get position
    position = data.findAll('td', {'class' : 'text'})[2].text
    
    #get height
    try :
        height_raw = data.findAll('td')[4].text
        height = transformPlayersHeightData(height_raw)
    except :
        height = None
        
    #get weight
    try :
        weight_raw = data.findAll('td', {'class' : 'text'})[3].text
        weight = transformPlayersWeightData(weight_raw)
    except :
        weight = None

    #get school
    school = data.findAll('td', {'class' : 'text'})[4].text

    #get country
    country = data.findAll('td', {'class' : 'text'})[5].text
    
    #insert all players data to container object
    players_container[full_name] = {
        'name' : full_name,
        'team' : team,
        'number' : number,
        'position' : position,
        'height' : height,
        'weight' : weight,
        'school' : school,
        'country' : country
    }

# %%
players_container
# Out:
# {'Precious Achiuwa': {'name': 'Precious Achiuwa',
#   'team': 'Miami Heat',
#   'number': 5,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 102,
#   'school': 'Memphis',
#   'country': 'Nigeria'},
#  'Jaylen Adams': {'name': 'Jaylen Adams',
#   'team': None,
#   'number': None,
#   'position': 'G',
#   'height': 182.9,
#   'weight': 102,
#   'school': 'St. Bonaventure',
#   'country': 'USA'},
#  'Steven Adams': {'name': 'Steven Adams',
#   'team': 'New Orleans Pelicans',
#   'number': 12,
#   'position': 'C',
#   'height': 186.2,
#   'weight': 120,
#   'school': 'Pittsburgh',
#   'country': 'New Zealand'},
#  'Bam Adebayo': {'name': 'Bam Adebayo',
#   'team': 'Miami Heat',
#   'number': 13,
#   'position': 'C-F',
#   'height': 210.3,
#   'weight': 115,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  'LaMarcus Aldridge': {'name': 'LaMarcus Aldridge',
#   'team': None,
#   'number': None,
#   'position': 'C-F',
#   'height': 186.2,
#   'weight': 113,
#   'school': 'Texas-Austin',
#   'country': 'USA'},
#  'Ty-Shon Alexander': {'name': 'Ty-Shon Alexander',
#   'team': 'Phoenix Suns',
#   'number': 0,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 88,
#   'school': 'Creighton',
#   'country': 'USA'},
#  'Nickeil Alexander-Walker': {'name': 'Nickeil Alexander-Walker',
#   'team': 'New Orleans Pelicans',
#   'number': 6,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 92,
#   'school': 'Virginia Tech',
#   'country': 'Canada'},
#  'Grayson Allen': {'name': 'Grayson Allen',
#   'team': 'Memphis Grizzlies',
#   'number': 3,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 89,
#   'school': 'Duke',
#   'country': 'USA'},
#  'Jarrett Allen': {'name': 'Jarrett Allen',
#   'team': 'Cleveland Cavaliers',
#   'number': 31,
#   'position': 'C',
#   'height': 186.2,
#   'weight': 110,
#   'school': 'Texas-Austin',
#   'country': 'USA'},
#  'Al-Farouq Aminu': {'name': 'Al-Farouq Aminu',
#   'team': 'Chicago Bulls',
#   'number': 5,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 99,
#   'school': 'Wake Forest',
#   'country': 'USA'},
#  'Kyle Anderson': {'name': 'Kyle Anderson',
#   'team': 'Memphis Grizzlies',
#   'number': 1,
#   'position': 'F-G',
#   'height': 210.3,
#   'weight': 104,
#   'school': 'UCLA',
#   'country': 'USA'},
#  'Giannis Antetokounmpo': {'name': 'Giannis Antetokounmpo',
#   'team': 'Milwaukee Bucks',
#   'number': 34,
#   'position': 'F',
#   'height': 186.2,
#   'weight': 109,
#   'school': 'Filathlitikos',
#   'country': 'Greece'},
#  'Kostas Antetokounmpo': {'name': 'Kostas Antetokounmpo',
#   'team': 'Los Angeles Lackers',
#   'number': 37,
#   'position': 'F',
#   'height': 185.9,
#   'weight': 90,
#   'school': 'Dayton',
#   'country': 'Greece'},
#  'Thanasis Antetokounmpo': {'name': 'Thanasis Antetokounmpo',
#   'team': 'Milwaukee Bucks',
#   'number': 43,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 99,
#   'school': 'Panathinaikos',
#   'country': 'Greece'},
#  'Carmelo Anthony': {'name': 'Carmelo Anthony',
#   'team': 'Portland Trail Blazers',
#   'number': 0,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 107,
#   'school': 'Syracuse',
#   'country': 'USA'},
#  'Cole Anthony': {'name': 'Cole Anthony',
#   'team': 'Orlando Magic',
#   'number': 50,
#   'position': 'G',
#   'height': 189.0,
#   'weight': 83,
#   'school': 'North Carolina',
#   'country': 'USA'},
#  'OG Anunoby': {'name': 'OG Anunoby',
#   'team': 'Toronto Raptors',
#   'number': 3,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 105,
#   'school': 'Indiana',
#   'country': 'United Kingdom'},
#  'Ryan Arcidiacono': {'name': 'Ryan Arcidiacono',
#   'team': 'Chicago Bulls',
#   'number': 51,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 88,
#   'school': 'Villanova',
#   'country': 'USA'},
#  'Trevor Ariza': {'name': 'Trevor Ariza',
#   'team': 'Miami Heat',
#   'number': 8,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 97,
#   'school': 'UCLA',
#   'country': 'USA'},
#  'D.J. Augustin': {'name': 'D.J. Augustin',
#   'team': 'Houston Rockets',
#   'number': 14,
#   'position': 'G',
#   'height': 155.8,
#   'weight': 82,
#   'school': 'Texas-Austin',
#   'country': 'USA'},
#  'Deni Avdija': {'name': 'Deni Avdija',
#   'team': 'Washington Wizards',
#   'number': 9,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 95,
#   'school': 'Maccabi Tel Aviv',
#   'country': 'Israel'},
#  'Deandre Ayton': {'name': 'Deandre Ayton',
#   'team': 'Phoenix Suns',
#   'number': 22,
#   'position': 'C',
#   'height': 186.2,
#   'weight': 113,
#   'school': 'Arizona',
#   'country': 'Bahamas'},
#  'Udoka Azubuike': {'name': 'Udoka Azubuike',
#   'team': 'Utah Jazz',
#   'number': 20,
#   'position': 'C-F',
#   'height': 185.9,
#   'weight': 126,
#   'school': 'Kansas',
#   'country': 'Nigeria'},
#  'Dwayne Bacon': {'name': 'Dwayne Bacon',
#   'team': 'Orlando Magic',
#   'number': 8,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 100,
#   'school': 'Florida State',
#   'country': 'USA'},
#  'Marvin Bagley III': {'name': 'Marvin Bagley III',
#   'team': 'Sacramento Kings',
#   'number': 35,
#   'position': 'F',
#   'height': 186.2,
#   'weight': 106,
#   'school': 'Duke',
#   'country': 'USA'},
#  'LaMelo Ball': {'name': 'LaMelo Ball',
#   'team': 'Charlotte Hornets',
#   'number': 2,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 81,
#   'school': 'Illawarra',
#   'country': 'USA'},
#  'Lonzo Ball': {'name': 'Lonzo Ball',
#   'team': 'New Orleans Pelicans',
#   'number': 2,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 86,
#   'school': 'UCLA',
#   'country': 'USA'},
#  'Mo Bamba': {'name': 'Mo Bamba',
#   'team': 'Orlando Magic',
#   'number': 5,
#   'position': 'C',
#   'height': 213.4,
#   'weight': 104,
#   'school': 'Texas-Austin',
#   'country': 'USA'},
#  'Desmond Bane': {'name': 'Desmond Bane',
#   'team': 'Memphis Grizzlies',
#   'number': 22,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 97,
#   'school': 'TCU',
#   'country': 'USA'},
#  'Harrison Barnes': {'name': 'Harrison Barnes',
#   'team': 'Sacramento Kings',
#   'number': 40,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 102,
#   'school': 'North Carolina',
#   'country': 'USA'},
#  'RJ Barrett': {'name': 'RJ Barrett',
#   'team': 'New York Knicks',
#   'number': 9,
#   'position': 'F-G',
#   'height': 201.2,
#   'weight': 97,
#   'school': 'Duke',
#   'country': 'Canada'},
#  'Will Barton': {'name': 'Will Barton',
#   'team': 'Denver Nuggets',
#   'number': 5,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 82,
#   'school': 'Memphis',
#   'country': 'USA'},
#  'Keita Bates-Diop': {'name': 'Keita Bates-Diop',
#   'team': 'San Antonio Spurs',
#   'number': 31,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 103,
#   'school': 'Ohio State',
#   'country': 'USA'},
#  'Nicolas Batum': {'name': 'Nicolas Batum',
#   'team': 'LA Clippers',
#   'number': 33,
#   'position': 'G-F',
#   'height': 207.3,
#   'weight': 104,
#   'school': 'Le Mans',
#   'country': 'France'},
#  'Aron Baynes': {'name': 'Aron Baynes',
#   'team': 'Toronto Raptors',
#   'number': 46,
#   'position': 'C-F',
#   'height': 185.9,
#   'weight': 117,
#   'school': 'Washington State',
#   'country': 'Australia'},
#  'Kent Bazemore': {'name': 'Kent Bazemore',
#   'team': 'Golden State Wariors',
#   'number': 26,
#   'position': 'G-F',
#   'height': 195.1,
#   'weight': 88,
#   'school': 'Old Dominion',
#   'country': 'USA'},
#  'Darius Bazley': {'name': 'Darius Bazley',
#   'team': 'Oklahoma Thunder',
#   'number': 7,
#   'position': 'F-G',
#   'height': 207.3,
#   'weight': 94,
#   'school': 'Princeton HS (OH)',
#   'country': 'USA'},
#  'Bradley Beal': {'name': 'Bradley Beal',
#   'team': 'Washington Wizards',
#   'number': 3,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 93,
#   'school': 'Florida',
#   'country': 'USA'},
#  'Malik Beasley': {'name': 'Malik Beasley',
#   'team': 'Minnesota Timberwolves',
#   'number': 5,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 84,
#   'school': 'Florida State',
#   'country': 'USA'},
#  'Jordan Bell': {'name': 'Jordan Bell',
#   'team': 'Golden State Wariors',
#   'number': 7,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 97,
#   'school': 'Oregon',
#   'country': 'USA'},
#  "DeAndre' Bembry": {'name': "DeAndre' Bembry",
#   'team': 'Toronto Raptors',
#   'number': 95,
#   'position': 'G-F',
#   'height': 198.1,
#   'weight': 95,
#   'school': "St. Joseph's (PA)",
#   'country': 'USA'},
#  'Davis Bertans': {'name': 'Davis Bertans',
#   'team': 'Washington Wizards',
#   'number': 42,
#   'position': 'F',
#   'height': 185.9,
#   'weight': 102,
#   'school': 'Baskonia',
#   'country': 'Latvia'},
#  'Patrick Beverley': {'name': 'Patrick Beverley',
#   'team': 'LA Clippers',
#   'number': 21,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 81,
#   'school': 'Arkansas',
#   'country': 'USA'},
#  'Saddiq Bey': {'name': 'Saddiq Bey',
#   'team': 'Detroit Pistons',
#   'number': 41,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 97,
#   'school': 'Villanova',
#   'country': 'USA'},
#  'Tyler Bey': {'name': 'Tyler Bey',
#   'team': 'Dallas Mavericks',
#   'number': 2,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 97,
#   'school': 'Colorado',
#   'country': 'USA'},
#  'Khem Birch': {'name': 'Khem Birch',
#   'team': 'Toronto Raptors',
#   'number': 24,
#   'position': 'C',
#   'height': 210.3,
#   'weight': 105,
#   'school': 'UNLV',
#   'country': 'Canada'},
#  'Goga Bitadze': {'name': 'Goga Bitadze',
#   'team': 'Indiana Pacers',
#   'number': 88,
#   'position': 'C-F',
#   'height': 186.2,
#   'weight': 113,
#   'school': 'Mega Basket',
#   'country': 'Georgia'},
#  'Bismack Biyombo': {'name': 'Bismack Biyombo',
#   'team': 'Charlotte Hornets',
#   'number': 8,
#   'position': 'C',
#   'height': 207.3,
#   'weight': 115,
#   'school': 'Baloncesto Fuenlabrada',
#   'country': 'DRC'},
#  'Nemanja Bjelica': {'name': 'Nemanja Bjelica',
#   'team': 'Miami Heat',
#   'number': 70,
#   'position': 'F',
#   'height': 185.9,
#   'weight': 106,
#   'school': 'Fenerbahce',
#   'country': 'Serbia'},
#  'Eric Bledsoe': {'name': 'Eric Bledsoe',
#   'team': 'New Orleans Pelicans',
#   'number': 5,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 97,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  'Keljin Blevins': {'name': 'Keljin Blevins',
#   'team': 'Portland Trail Blazers',
#   'number': 21,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 90,
#   'school': 'Montana State',
#   'country': 'USA'},
#  'Bogdan Bogdanovic': {'name': 'Bogdan Bogdanovic',
#   'team': 'Atlanta Hawks',
#   'number': 13,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 99,
#   'school': 'Fenerbahce',
#   'country': 'Serbia'},
#  'Bojan Bogdanovic': {'name': 'Bojan Bogdanovic',
#   'team': 'Utah Jazz',
#   'number': 44,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 102,
#   'school': 'Fenerbahce',
#   'country': 'Croatia'},
#  'Bol Bol': {'name': 'Bol Bol',
#   'team': 'Denver Nuggets',
#   'number': 10,
#   'position': 'C-F',
#   'height': 219.5,
#   'weight': 99,
#   'school': 'Oregon',
#   'country': 'Sudan'},
#  'Marques Bolden': {'name': 'Marques Bolden',
#   'team': None,
#   'number': None,
#   'position': 'C',
#   'height': 185.9,
#   'weight': 112,
#   'school': 'Duke',
#   'country': 'USA'},
#  'Jordan Bone': {'name': 'Jordan Bone',
#   'team': None,
#   'number': None,
#   'position': 'G',
#   'height': 189.0,
#   'weight': 81,
#   'school': 'Tennessee',
#   'country': 'USA'},
#  'Isaac Bonga': {'name': 'Isaac Bonga',
#   'team': 'Washington Wizards',
#   'number': 17,
#   'position': 'G',
#   'height': 207.3,
#   'weight': 81,
#   'school': 'Skyliners Frankfurt',
#   'country': 'Germany'},
#  'Devin Booker': {'name': 'Devin Booker',
#   'team': 'Phoenix Suns',
#   'number': 1,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 93,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  'Chris Boucher': {'name': 'Chris Boucher',
#   'team': 'Toronto Raptors',
#   'number': 25,
#   'position': 'F-C',
#   'height': 210.3,
#   'weight': 90,
#   'school': 'Oregon',
#   'country': 'Saint Lucia'},
#  'Brian Bowen II': {'name': 'Brian Bowen II',
#   'team': None,
#   'number': None,
#   'position': 'F-G',
#   'height': 201.2,
#   'weight': 86,
#   'school': ' ',
#   'country': 'USA'},
#  'Avery Bradley': {'name': 'Avery Bradley',
#   'team': 'Houston Rockets',
#   'number': 9,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 81,
#   'school': 'Texas-Austin',
#   'country': 'USA'},
#  'Tony Bradley': {'name': 'Tony Bradley',
#   'team': 'Oklahoma Thunder',
#   'number': 13,
#   'position': 'C-F',
#   'height': 185.9,
#   'weight': 112,
#   'school': 'North Carolina',
#   'country': 'USA'},
#  'Jarrell Brantley': {'name': 'Jarrell Brantley',
#   'team': 'Utah Jazz',
#   'number': 5,
#   'position': 'F',
#   'height': 198.1,
#   'weight': 113,
#   'school': 'College of Charleston',
#   'country': 'USA'},
#  'Ignas Brazdeikis': {'name': 'Ignas Brazdeikis',
#   'team': 'Orlando Magic',
#   'number': 17,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 100,
#   'school': 'Michigan',
#   'country': 'Canada'},
#  'Mikal Bridges': {'name': 'Mikal Bridges',
#   'team': 'Phoenix Suns',
#   'number': 25,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 94,
#   'school': 'Villanova',
#   'country': 'USA'},
#  'Miles Bridges': {'name': 'Miles Bridges',
#   'team': 'Charlotte Hornets',
#   'number': 0,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 102,
#   'school': 'Michigan State',
#   'country': 'USA'},
#  'Amida Brimah': {'name': 'Amida Brimah',
#   'team': 'Indiana Pacers',
#   'number': 37,
#   'position': 'C',
#   'height': 185.9,
#   'weight': 104,
#   'school': 'Connecticut',
#   'country': 'USA'},
#  'Oshae Brissett': {'name': 'Oshae Brissett',
#   'team': 'Indiana Pacers',
#   'number': 12,
#   'position': 'F-G',
#   'height': 204.2,
#   'weight': 95,
#   'school': 'Syracuse',
#   'country': 'Canada'},
#  'Malcolm Brogdon': {'name': 'Malcolm Brogdon',
#   'team': 'Indiana Pacers',
#   'number': 7,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 103,
#   'school': 'Virginia',
#   'country': 'USA'},
#  'Armoni Brooks': {'name': 'Armoni Brooks',
#   'team': 'Houston Rockets',
#   'number': 7,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 88,
#   'school': 'Houston',
#   'country': 'USA'},
#  'Dillon Brooks': {'name': 'Dillon Brooks',
#   'team': 'Memphis Grizzlies',
#   'number': 24,
#   'position': 'G-F',
#   'height': 204.2,
#   'weight': 102,
#   'school': 'Oregon',
#   'country': 'Canada'},
#  'Bruce Brown': {'name': 'Bruce Brown',
#   'team': 'Brooklyn Nets',
#   'number': 1,
#   'position': 'G-F',
#   'height': 195.1,
#   'weight': 91,
#   'school': 'Miami',
#   'country': 'USA'},
#  'Jaylen Brown': {'name': 'Jaylen Brown',
#   'team': 'Boston Celtics',
#   'number': 7,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 101,
#   'school': 'California',
#   'country': 'USA'},
#  'Moses Brown': {'name': 'Moses Brown',
#   'team': 'Boston Celtics',
#   'number': 9,
#   'position': 'C',
#   'height': 219.5,
#   'weight': 111,
#   'school': 'UCLA',
#   'country': 'USA'},
#  'Sterling Brown': {'name': 'Sterling Brown',
#   'team': 'Houston Rockets',
#   'number': 0,
#   'position': 'G-F',
#   'height': 198.1,
#   'weight': 99,
#   'school': 'Southern Methodist',
#   'country': 'USA'},
#  'Charlie Brown Jr.': {'name': 'Charlie Brown Jr.',
#   'team': 'Oklahoma Thunder',
#   'number': 44,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 90,
#   'school': "St. Joseph's (PA)",
#   'country': 'USA'},
#  'Troy Brown Jr.': {'name': 'Troy Brown Jr.',
#   'team': 'Chicago Bulls',
#   'number': 7,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 97,
#   'school': 'Oregon',
#   'country': 'USA'},
#  'Jalen Brunson': {'name': 'Jalen Brunson',
#   'team': 'Dallas Mavericks',
#   'number': 13,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 86,
#   'school': 'Villanova',
#   'country': 'USA'},
#  'Elijah Bryant': {'name': 'Elijah Bryant',
#   'team': 'Milwaukee Bucks',
#   'number': None,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 95,
#   'school': 'Brigham Young',
#   'country': 'USA'},
#  'Thomas Bryant': {'name': 'Thomas Bryant',
#   'team': 'Washington Wizards',
#   'number': 13,
#   'position': 'C-F',
#   'height': 185.9,
#   'weight': 112,
#   'school': 'Indiana',
#   'country': 'USA'},
#  'Reggie Bullock': {'name': 'Reggie Bullock',
#   'team': 'New York Knicks',
#   'number': 25,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 92,
#   'school': 'North Carolina',
#   'country': 'USA'},
#  'Trey Burke': {'name': 'Trey Burke',
#   'team': 'Dallas Mavericks',
#   'number': 3,
#   'position': 'G',
#   'height': 182.9,
#   'weight': 83,
#   'school': 'Michigan',
#   'country': 'USA'},
#  'Alec Burks': {'name': 'Alec Burks',
#   'team': 'New York Knicks',
#   'number': 18,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 97,
#   'school': 'Colorado',
#   'country': 'USA'},
#  'Jimmy Butler': {'name': 'Jimmy Butler',
#   'team': 'Miami Heat',
#   'number': 22,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 104,
#   'school': 'Marquette',
#   'country': 'USA'},
#  'Bruno Caboclo': {'name': 'Bruno Caboclo',
#   'team': None,
#   'number': None,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 98,
#   'school': '',
#   'country': 'Brazil'},
#  'Devontae Cacok': {'name': 'Devontae Cacok',
#   'team': 'Los Angeles Lackers',
#   'number': 12,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 108,
#   'school': 'North Carolina-Wilmington',
#   'country': 'USA'},
#  'Kentavious Caldwell-Pope': {'name': 'Kentavious Caldwell-Pope',
#   'team': 'Los Angeles Lackers',
#   'number': 1,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 92,
#   'school': 'Georgia',
#   'country': 'USA'},
#  'Facundo Campazzo': {'name': 'Facundo Campazzo',
#   'team': 'Denver Nuggets',
#   'number': 7,
#   'position': 'G',
#   'height': 155.4,
#   'weight': 88,
#   'school': 'Murcia',
#   'country': 'Argentina'},
#  'Vlatko Cancar': {'name': 'Vlatko Cancar',
#   'team': 'Denver Nuggets',
#   'number': 31,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 107,
#   'school': 'San Pablo Burgos',
#   'country': 'Slovenia'},
#  'Devin Cannady': {'name': 'Devin Cannady',
#   'team': None,
#   'number': None,
#   'position': 'G',
#   'height': 189.0,
#   'weight': 82,
#   'school': 'Princeton',
#   'country': 'USA'},
#  'Clint Capela': {'name': 'Clint Capela',
#   'team': 'Atlanta Hawks',
#   'number': 15,
#   'position': 'C',
#   'height': 185.9,
#   'weight': 108,
#   'school': 'Elan Chalon',
#   'country': 'Switzerland'},
#  'Vernon Carey Jr.': {'name': 'Vernon Carey Jr.',
#   'team': 'Charlotte Hornets',
#   'number': 22,
#   'position': 'F-C',
#   'height': 210.3,
#   'weight': 122,
#   'school': 'Duke',
#   'country': 'USA'},
#  'Jevon Carter': {'name': 'Jevon Carter',
#   'team': 'Phoenix Suns',
#   'number': 4,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 90,
#   'school': 'West Virginia',
#   'country': 'USA'},
#  'Wendell Carter Jr.': {'name': 'Wendell Carter Jr.',
#   'team': 'Orlando Magic',
#   'number': 34,
#   'position': 'C-F',
#   'height': 185.9,
#   'weight': 122,
#   'school': 'Duke',
#   'country': 'USA'},
#  'Michael Carter-Williams': {'name': 'Michael Carter-Williams',
#   'team': 'Orlando Magic',
#   'number': 7,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 86,
#   'school': 'Syracuse',
#   'country': 'USA'},
#  'Alex Caruso': {'name': 'Alex Caruso',
#   'team': 'Los Angeles Lackers',
#   'number': 4,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 84,
#   'school': 'Texas A&M',
#   'country': 'USA'},
#  'Willie Cauley-Stein': {'name': 'Willie Cauley-Stein',
#   'team': 'Dallas Mavericks',
#   'number': 33,
#   'position': 'C',
#   'height': 213.4,
#   'weight': 108,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  'Chris Chiozza': {'name': 'Chris Chiozza',
#   'team': 'Brooklyn Nets',
#   'number': 4,
#   'position': 'G',
#   'height': 155.8,
#   'weight': 79,
#   'school': 'Florida',
#   'country': 'USA'},
#  'Marquese Chriss': {'name': 'Marquese Chriss',
#   'team': None,
#   'number': None,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 108,
#   'school': 'Washington',
#   'country': 'USA'},
#  'Gary Clark': {'name': 'Gary Clark',
#   'team': 'Philadelphia 76ers',
#   'number': 12,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 102,
#   'school': 'Cincinnati',
#   'country': 'USA'},
#  'Brandon Clarke': {'name': 'Brandon Clarke',
#   'team': 'Memphis Grizzlies',
#   'number': 15,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 97,
#   'school': 'Gonzaga',
#   'country': 'Canada'},
#  'Jordan Clarkson': {'name': 'Jordan Clarkson',
#   'team': 'Utah Jazz',
#   'number': 0,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 87,
#   'school': 'Missouri',
#   'country': 'USA'},
#  'Nicolas Claxton': {'name': 'Nicolas Claxton',
#   'team': 'Brooklyn Nets',
#   'number': 33,
#   'position': 'F-C',
#   'height': 186.2,
#   'weight': 97,
#   'school': 'Georgia',
#   'country': 'USA'},
#  'Amir Coffey': {'name': 'Amir Coffey',
#   'team': 'LA Clippers',
#   'number': 7,
#   'position': 'G-F',
#   'height': 204.2,
#   'weight': 95,
#   'school': 'Minnesota',
#   'country': 'USA'},
#  'John Collins': {'name': 'John Collins',
#   'team': 'Atlanta Hawks',
#   'number': 20,
#   'position': 'F-C',
#   'height': 210.3,
#   'weight': 106,
#   'school': 'Wake Forest',
#   'country': 'USA'},
#  'Zach Collins': {'name': 'Zach Collins',
#   'team': 'Portland Trail Blazers',
#   'number': 33,
#   'position': 'F-C',
#   'height': 186.2,
#   'weight': 113,
#   'school': 'Gonzaga',
#   'country': 'USA'},
#  'Mike Conley': {'name': 'Mike Conley',
#   'team': 'Utah Jazz',
#   'number': 10,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 79,
#   'school': 'Ohio State',
#   'country': 'USA'},
#  'Pat Connaughton': {'name': 'Pat Connaughton',
#   'team': 'Milwaukee Bucks',
#   'number': 24,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 94,
#   'school': 'Notre Dame',
#   'country': 'USA'},
#  'Quinn Cook': {'name': 'Quinn Cook',
#   'team': None,
#   'number': None,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 81,
#   'school': 'Duke',
#   'country': 'USA'},
#  'Tyler Cook': {'name': 'Tyler Cook',
#   'team': 'Detroit Pistons',
#   'number': 25,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 115,
#   'school': 'Iowa',
#   'country': 'USA'},
#  'DeMarcus Cousins': {'name': 'DeMarcus Cousins',
#   'team': 'LA Clippers',
#   'number': 15,
#   'position': 'C',
#   'height': 185.9,
#   'weight': 122,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  'Robert Covington': {'name': 'Robert Covington',
#   'team': 'Portland Trail Blazers',
#   'number': 23,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 94,
#   'school': 'Tennessee State',
#   'country': 'USA'},
#  'Torrey Craig': {'name': 'Torrey Craig',
#   'team': 'Phoenix Suns',
#   'number': 12,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 100,
#   'school': 'South Carolina Upstate',
#   'country': 'USA'},
#  'Jae Crowder': {'name': 'Jae Crowder',
#   'team': 'Phoenix Suns',
#   'number': 99,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 106,
#   'school': 'Marquette',
#   'country': 'USA'},
#  'Jarrett Culver': {'name': 'Jarrett Culver',
#   'team': 'Minnesota Timberwolves',
#   'number': 23,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 88,
#   'school': 'Texas Tech',
#   'country': 'USA'},
#  'Seth Curry': {'name': 'Seth Curry',
#   'team': 'Philadelphia 76ers',
#   'number': 31,
#   'position': 'G',
#   'height': 189.0,
#   'weight': 83,
#   'school': 'Duke',
#   'country': 'USA'},
#  'Stephen Curry': {'name': 'Stephen Curry',
#   'team': 'Golden State Wariors',
#   'number': 30,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 83,
#   'school': 'Davidson',
#   'country': 'USA'},
#  'Nate Darling': {'name': 'Nate Darling',
#   'team': 'Charlotte Hornets',
#   'number': 30,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 90,
#   'school': 'Delaware',
#   'country': 'Canada'},
#  'Anthony Davis': {'name': 'Anthony Davis',
#   'team': 'Los Angeles Lackers',
#   'number': 3,
#   'position': 'F-C',
#   'height': 185.9,
#   'weight': 114,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  'Ed Davis': {'name': 'Ed Davis',
#   'team': 'Minnesota Timberwolves',
#   'number': 17,
#   'position': 'C-F',
#   'height': 210.3,
#   'weight': 98,
#   'school': 'North Carolina',
#   'country': 'USA'},
#  'Terence Davis': {'name': 'Terence Davis',
#   'team': 'Sacramento Kings',
#   'number': 9,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 91,
#   'school': 'Mississippi',
#   'country': 'USA'},
#  'DeMar DeRozan': {'name': 'DeMar DeRozan',
#   'team': 'San Antonio Spurs',
#   'number': 10,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 99,
#   'school': 'Southern California',
#   'country': 'USA'},
#  'Gabriel Deck': {'name': 'Gabriel Deck',
#   'team': 'Oklahoma Thunder',
#   'number': 6,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 104,
#   'school': 'Real Madrid',
#   'country': 'Argentina'},
#  'Dewayne Dedmon': {'name': 'Dewayne Dedmon',
#   'team': 'Miami Heat',
#   'number': 21,
#   'position': 'C',
#   'height': 213.4,
#   'weight': 111,
#   'school': 'Southern California',
#   'country': 'USA'},
#  'Matthew Dellavedova': {'name': 'Matthew Dellavedova',
#   'team': 'Cleveland Cavaliers',
#   'number': 18,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 90,
#   'school': "St.Mary's College of California",
#   'country': 'Australia'},
#  'Donte DiVincenzo': {'name': 'Donte DiVincenzo',
#   'team': 'Milwaukee Bucks',
#   'number': 0,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 92,
#   'school': 'Villanova',
#   'country': 'USA'},
#  'Mamadi Diakite': {'name': 'Mamadi Diakite',
#   'team': 'Milwaukee Bucks',
#   'number': 25,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 103,
#   'school': 'Virginia',
#   'country': 'Guinea'},
#  'Hamidou Diallo': {'name': 'Hamidou Diallo',
#   'team': 'Detroit Pistons',
#   'number': 6,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 91,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  'Gorgui Dieng': {'name': 'Gorgui Dieng',
#   'team': 'San Antonio Spurs',
#   'number': 7,
#   'position': 'C',
#   'height': 185.9,
#   'weight': 114,
#   'school': 'Louisville',
#   'country': 'Senegal'},
#  'Spencer Dinwiddie': {'name': 'Spencer Dinwiddie',
#   'team': 'Brooklyn Nets',
#   'number': 26,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 97,
#   'school': 'Colorado',
#   'country': 'USA'},
#  'Luka Doncic': {'name': 'Luka Doncic',
#   'team': 'Dallas Mavericks',
#   'number': 77,
#   'position': 'F-G',
#   'height': 204.2,
#   'weight': 104,
#   'school': 'Real Madrid',
#   'country': 'Slovenia'},
#  'Luguentz Dort': {'name': 'Luguentz Dort',
#   'team': 'Oklahoma Thunder',
#   'number': 5,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 97,
#   'school': 'Arizona State',
#   'country': 'Canada'},
#  'Damyean Dotson': {'name': 'Damyean Dotson',
#   'team': 'Cleveland Cavaliers',
#   'number': 21,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 95,
#   'school': 'Houston',
#   'country': 'USA'},
#  'Devon Dotson': {'name': 'Devon Dotson',
#   'team': 'Chicago Bulls',
#   'number': 3,
#   'position': 'G',
#   'height': 189.0,
#   'weight': 83,
#   'school': 'Kansas',
#   'country': 'USA'},
#  'Sekou Doumbouya': {'name': 'Sekou Doumbouya',
#   'team': 'Detroit Pistons',
#   'number': 45,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 104,
#   'school': 'Limoges',
#   'country': 'France'},
#  'PJ Dozier': {'name': 'PJ Dozier',
#   'team': 'Denver Nuggets',
#   'number': 35,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 92,
#   'school': 'South Carolina',
#   'country': 'USA'},
#  'Goran Dragic': {'name': 'Goran Dragic',
#   'team': 'Miami Heat',
#   'number': 7,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 86,
#   'school': 'Union Olimpija',
#   'country': 'Slovenia'},
#  'Andre Drummond': {'name': 'Andre Drummond',
#   'team': 'Los Angeles Lackers',
#   'number': 2,
#   'position': 'C',
#   'height': 185.9,
#   'weight': 126,
#   'school': 'Connecticut',
#   'country': 'USA'},
#  'Jared Dudley': {'name': 'Jared Dudley',
#   'team': 'Los Angeles Lackers',
#   'number': 10,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 107,
#   'school': 'Boston College',
#   'country': 'USA'},
#  'Kris Dunn': {'name': 'Kris Dunn',
#   'team': 'Atlanta Hawks',
#   'number': 32,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 92,
#   'school': 'Providence',
#   'country': 'USA'},
#  'Kevin Durant': {'name': 'Kevin Durant',
#   'team': 'Brooklyn Nets',
#   'number': 7,
#   'position': 'F',
#   'height': 185.9,
#   'weight': 108,
#   'school': 'Texas-Austin',
#   'country': 'USA'},
#  'Anthony Edwards': {'name': 'Anthony Edwards',
#   'team': 'Minnesota Timberwolves',
#   'number': 1,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 102,
#   'school': 'Georgia',
#   'country': 'USA'},
#  'Carsen Edwards': {'name': 'Carsen Edwards',
#   'team': 'Boston Celtics',
#   'number': 4,
#   'position': 'G',
#   'height': 155.8,
#   'weight': 90,
#   'school': 'Purdue',
#   'country': 'USA'},
#  'CJ Elleby': {'name': 'CJ Elleby',
#   'team': 'Portland Trail Blazers',
#   'number': 16,
#   'position': 'F-G',
#   'height': 201.2,
#   'weight': 90,
#   'school': 'Washington State',
#   'country': 'USA'},
#  'Henry Ellenson': {'name': 'Henry Ellenson',
#   'team': None,
#   'number': None,
#   'position': 'F-C',
#   'height': 185.9,
#   'weight': 108,
#   'school': 'Marquette',
#   'country': 'USA'},
#  'Wayne Ellington': {'name': 'Wayne Ellington',
#   'team': 'Detroit Pistons',
#   'number': 8,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 93,
#   'school': 'North Carolina',
#   'country': 'USA'},
#  'Joel Embiid': {'name': 'Joel Embiid',
#   'team': 'Philadelphia 76ers',
#   'number': 21,
#   'position': 'C-F',
#   'height': 213.4,
#   'weight': 126,
#   'school': 'Kansas',
#   'country': 'Cameroon'},
#  'James Ennis III': {'name': 'James Ennis III',
#   'team': 'Orlando Magic',
#   'number': 11,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 97,
#   'school': 'California State-Long Beach',
#   'country': 'USA'},
#  'Drew Eubanks': {'name': 'Drew Eubanks',
#   'team': 'San Antonio Spurs',
#   'number': 14,
#   'position': 'F-C',
#   'height': 210.3,
#   'weight': 111,
#   'school': 'Oregon State',
#   'country': 'USA'},
#  'Dante Exum': {'name': 'Dante Exum',
#   'team': 'Houston Rockets',
#   'number': 5,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 97,
#   'school': 'Australian Institute of Sport',
#   'country': 'Australia'},
#  'Tacko Fall': {'name': 'Tacko Fall',
#   'team': 'Boston Celtics',
#   'number': 99,
#   'position': 'C',
#   'height': 228.6,
#   'weight': 141,
#   'school': 'Central Florida',
#   'country': 'Senegal'},
#  'Derrick Favors': {'name': 'Derrick Favors',
#   'team': 'Utah Jazz',
#   'number': 15,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 120,
#   'school': 'Georgia Tech',
#   'country': 'USA'},
#  'Cristiano Felicio': {'name': 'Cristiano Felicio',
#   'team': 'Chicago Bulls',
#   'number': 6,
#   'position': 'F-C',
#   'height': 186.2,
#   'weight': 122,
#   'school': 'Flamengo',
#   'country': 'Brazil'},
#  'Terrance Ferguson': {'name': 'Terrance Ferguson',
#   'team': None,
#   'number': None,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 86,
#   'school': '',
#   'country': 'USA'},
#  'Bruno Fernando': {'name': 'Bruno Fernando',
#   'team': 'Atlanta Hawks',
#   'number': 24,
#   'position': 'F-C',
#   'height': 210.3,
#   'weight': 108,
#   'school': 'Maryland',
#   'country': 'Angola'},
#  'Yogi Ferrell': {'name': 'Yogi Ferrell',
#   'team': 'LA Clippers',
#   'number': 11,
#   'position': 'G',
#   'height': 182.9,
#   'weight': 80,
#   'school': 'Indiana',
#   'country': 'USA'},
#  'Dorian Finney-Smith': {'name': 'Dorian Finney-Smith',
#   'team': 'Dallas Mavericks',
#   'number': 10,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 99,
#   'school': 'Florida',
#   'country': 'USA'},
#  'Malik Fitts': {'name': 'Malik Fitts',
#   'team': None,
#   'number': None,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 104,
#   'school': '-',
#   'country': 'USA'},
#  'Malachi Flynn': {'name': 'Malachi Flynn',
#   'team': 'Toronto Raptors',
#   'number': 8,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 79,
#   'school': 'San Diego State',
#   'country': 'USA'},
#  'Bryn Forbes': {'name': 'Bryn Forbes',
#   'team': 'Milwaukee Bucks',
#   'number': 7,
#   'position': 'G',
#   'height': 189.0,
#   'weight': 92,
#   'school': 'Michigan State',
#   'country': 'USA'},
#  'Trent Forrest': {'name': 'Trent Forrest',
#   'team': 'Utah Jazz',
#   'number': 3,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 95,
#   'school': 'Florida State',
#   'country': 'USA'},
#  'Evan Fournier': {'name': 'Evan Fournier',
#   'team': 'Boston Celtics',
#   'number': 94,
#   'position': 'G-F',
#   'height': 204.2,
#   'weight': 92,
#   'school': 'Poitiers Basket 86',
#   'country': 'France'},
#  "De'Aaron Fox": {'name': "De'Aaron Fox",
#   'team': 'Sacramento Kings',
#   'number': 5,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 83,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  'Robert Franks': {'name': 'Robert Franks',
#   'team': None,
#   'number': None,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 102,
#   'school': 'Washington State',
#   'country': 'USA'},
#  'Tim Frazier': {'name': 'Tim Frazier',
#   'team': 'Memphis Grizzlies',
#   'number': 10,
#   'position': 'G',
#   'height': 182.9,
#   'weight': 77,
#   'school': 'Penn State',
#   'country': 'USA'},
#  'Markelle Fultz': {'name': 'Markelle Fultz',
#   'team': 'Orlando Magic',
#   'number': 20,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 94,
#   'school': 'Washington',
#   'country': 'USA'},
#  'Wenyen Gabriel': {'name': 'Wenyen Gabriel',
#   'team': 'New Orleans Pelicans',
#   'number': 32,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 92,
#   'school': 'Kentucky',
#   'country': 'South Sudan'},
#  'Daniel Gafford': {'name': 'Daniel Gafford',
#   'team': 'Washington Wizards',
#   'number': 21,
#   'position': 'F-C',
#   'height': 185.9,
#   'weight': 106,
#   'school': 'Arkansas',
#   'country': 'USA'},
#  'Danilo Gallinari': {'name': 'Danilo Gallinari',
#   'team': 'Atlanta Hawks',
#   'number': 8,
#   'position': 'F',
#   'height': 185.9,
#   'weight': 105,
#   'school': 'Olimpia Milano',
#   'country': 'Italy'},
#  'Langston Galloway': {'name': 'Langston Galloway',
#   'team': 'Phoenix Suns',
#   'number': 2,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 90,
#   'school': "St. Joseph's (PA)",
#   'country': 'USA'},
#  'Darius Garland': {'name': 'Darius Garland',
#   'team': 'Cleveland Cavaliers',
#   'number': 10,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 87,
#   'school': 'Vanderbilt',
#   'country': 'USA'},
#  'Marc Gasol': {'name': 'Marc Gasol',
#   'team': 'Los Angeles Lackers',
#   'number': 14,
#   'position': 'C',
#   'height': 186.2,
#   'weight': 115,
#   'school': 'FC Barcelona',
#   'country': 'Spain'},
#  'Rudy Gay': {'name': 'Rudy Gay',
#   'team': 'San Antonio Spurs',
#   'number': 22,
#   'position': 'F-G',
#   'height': 207.3,
#   'weight': 113,
#   'school': 'Connecticut',
#   'country': 'USA'},
#  'Paul George': {'name': 'Paul George',
#   'team': 'LA Clippers',
#   'number': 13,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 99,
#   'school': 'Fresno State',
#   'country': 'USA'},
#  'Taj Gibson': {'name': 'Taj Gibson',
#   'team': 'New York Knicks',
#   'number': 67,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 105,
#   'school': 'Southern California',
#   'country': 'USA'},
#  'Harry Giles III': {'name': 'Harry Giles III',
#   'team': 'Portland Trail Blazers',
#   'number': 4,
#   'position': 'F-C',
#   'height': 186.2,
#   'weight': 108,
#   'school': 'Duke',
#   'country': 'USA'},
#  'Shai Gilgeous-Alexander': {'name': 'Shai Gilgeous-Alexander',
#   'team': 'Oklahoma Thunder',
#   'number': 2,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 81,
#   'school': 'Kentucky',
#   'country': 'Canada'},
#  'Anthony Gill': {'name': 'Anthony Gill',
#   'team': 'Washington Wizards',
#   'number': 16,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 104,
#   'school': 'Virginia',
#   'country': 'USA'},
#  'Freddie Gillespie': {'name': 'Freddie Gillespie',
#   'team': 'Toronto Raptors',
#   'number': None,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 111,
#   'school': 'Baylor',
#   'country': 'USA'},
#  'Rudy Gobert': {'name': 'Rudy Gobert',
#   'team': 'Utah Jazz',
#   'number': 27,
#   'position': 'C',
#   'height': 216.4,
#   'weight': 117,
#   'school': 'Cholet',
#   'country': 'France'},
#  'Brandon Goodwin': {'name': 'Brandon Goodwin',
#   'team': 'Atlanta Hawks',
#   'number': 0,
#   'position': 'G',
#   'height': 182.9,
#   'weight': 81,
#   'school': 'Florida Gulf Coast',
#   'country': 'USA'},
#  'Aaron Gordon': {'name': 'Aaron Gordon',
#   'team': 'Denver Nuggets',
#   'number': 50,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 106,
#   'school': 'Arizona',
#   'country': 'USA'},
#  'Eric Gordon': {'name': 'Eric Gordon',
#   'team': 'Houston Rockets',
#   'number': 10,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 97,
#   'school': 'Indiana',
#   'country': 'USA'},
#  "Devonte' Graham": {'name': "Devonte' Graham",
#   'team': 'Charlotte Hornets',
#   'number': 4,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 88,
#   'school': 'Kansas',
#   'country': 'USA'},
#  'Jerami Grant': {'name': 'Jerami Grant',
#   'team': 'Detroit Pistons',
#   'number': 9,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 95,
#   'school': 'Syracuse',
#   'country': 'USA'},
#  'Danny Green': {'name': 'Danny Green',
#   'team': 'Philadelphia 76ers',
#   'number': 14,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 97,
#   'school': 'North Carolina',
#   'country': 'USA'},
#  'Draymond Green': {'name': 'Draymond Green',
#   'team': 'Golden State Wariors',
#   'number': 23,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 104,
#   'school': 'Michigan State',
#   'country': 'USA'},
#  'JaMychal Green': {'name': 'JaMychal Green',
#   'team': 'Denver Nuggets',
#   'number': 0,
#   'position': 'F-C',
#   'height': 207.3,
#   'weight': 102,
#   'school': 'Alabama',
#   'country': 'USA'},
#  'Javonte Green': {'name': 'Javonte Green',
#   'team': 'Chicago Bulls',
#   'number': 11,
#   'position': 'G-F',
#   'height': 195.1,
#   'weight': 92,
#   'school': 'Radford',
#   'country': 'USA'},
#  'Jeff Green': {'name': 'Jeff Green',
#   'team': 'Brooklyn Nets',
#   'number': 8,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 106,
#   'school': 'Georgetown',
#   'country': 'USA'},
#  'Josh Green': {'name': 'Josh Green',
#   'team': 'Dallas Mavericks',
#   'number': 8,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 90,
#   'school': 'Arizona',
#   'country': 'Australia'},
#  'Blake Griffin': {'name': 'Blake Griffin',
#   'team': 'Brooklyn Nets',
#   'number': 2,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 113,
#   'school': 'Oklahoma',
#   'country': 'USA'},
#  'Kyle Guy': {'name': 'Kyle Guy',
#   'team': 'Sacramento Kings',
#   'number': 7,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 75,
#   'school': 'Virginia',
#   'country': 'USA'},
#  'Rui Hachimura': {'name': 'Rui Hachimura',
#   'team': 'Washington Wizards',
#   'number': 8,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 104,
#   'school': 'Gonzaga',
#   'country': 'Japan'},
#  'Ashton Hagans': {'name': 'Ashton Hagans',
#   'team': None,
#   'number': None,
#   'position': 'G-F',
#   'height': 192.0,
#   'weight': 86,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  'Tyrese Haliburton': {'name': 'Tyrese Haliburton',
#   'team': 'Sacramento Kings',
#   'number': 0,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 83,
#   'school': 'Iowa State',
#   'country': 'USA'},
#  'Donta Hall': {'name': 'Donta Hall',
#   'team': None,
#   'number': None,
#   'position': 'C',
#   'height': 185.9,
#   'weight': 104,
#   'school': 'Alabama',
#   'country': 'USA'},
#  'Josh Hall': {'name': 'Josh Hall',
#   'team': 'Oklahoma Thunder',
#   'number': 15,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 86,
#   'school': 'Moravian Prep (NC)',
#   'country': 'USA'},
#  'R.J. Hampton': {'name': 'R.J. Hampton',
#   'team': 'Orlando Magic',
#   'number': 13,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 79,
#   'school': 'New Zealand Breakers',
#   'country': 'USA'},
#  'Tim Hardaway Jr.': {'name': 'Tim Hardaway Jr.',
#   'team': 'Dallas Mavericks',
#   'number': 11,
#   'position': 'G-F',
#   'height': 198.1,
#   'weight': 92,
#   'school': 'Michigan',
#   'country': 'USA'},
#  'James Harden': {'name': 'James Harden',
#   'team': 'Brooklyn Nets',
#   'number': 13,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 99,
#   'school': 'Arizona State',
#   'country': 'USA'},
#  'Maurice Harkless': {'name': 'Maurice Harkless',
#   'team': 'Sacramento Kings',
#   'number': 8,
#   'position': 'F-G',
#   'height': 204.2,
#   'weight': 99,
#   'school': "St. John's",
#   'country': 'USA'},
#  'Jared Harper': {'name': 'Jared Harper',
#   'team': 'New York Knicks',
#   'number': 0,
#   'position': 'G',
#   'height': 155.4,
#   'weight': 79,
#   'school': 'Auburn',
#   'country': 'USA'},
#  'Montrezl Harrell': {'name': 'Montrezl Harrell',
#   'team': 'Los Angeles Lackers',
#   'number': 15,
#   'position': 'F-C',
#   'height': 204.2,
#   'weight': 108,
#   'school': 'Louisville',
#   'country': 'USA'},
#  'Gary Harris': {'name': 'Gary Harris',
#   'team': 'Orlando Magic',
#   'number': 14,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 95,
#   'school': 'Michigan State',
#   'country': 'USA'},
#  'Jalen Harris': {'name': 'Jalen Harris',
#   'team': None,
#   'number': None,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 88,
#   'school': 'Nevada',
#   'country': 'USA'},
#  'Joe Harris': {'name': 'Joe Harris',
#   'team': 'Brooklyn Nets',
#   'number': 12,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 99,
#   'school': 'Virginia',
#   'country': 'USA'},
#  'Tobias Harris': {'name': 'Tobias Harris',
#   'team': 'Philadelphia 76ers',
#   'number': 12,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 102,
#   'school': 'Tennessee',
#   'country': 'USA'},
#  'Shaquille Harrison': {'name': 'Shaquille Harrison',
#   'team': 'Denver Nuggets',
#   'number': 3,
#   'position': 'G',
#   'height': 204.2,
#   'weight': 86,
#   'school': 'Tulsa',
#   'country': 'USA'},
#  'Josh Hart': {'name': 'Josh Hart',
#   'team': 'New Orleans Pelicans',
#   'number': 3,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 97,
#   'school': 'Villanova',
#   'country': 'USA'},
#  'Isaiah Hartenstein': {'name': 'Isaiah Hartenstein',
#   'team': 'Cleveland Cavaliers',
#   'number': 55,
#   'position': 'C-F',
#   'height': 213.4,
#   'weight': 113,
#   'school': 'Zalgiris',
#   'country': 'Germany'},
#  'Udonis Haslem': {'name': 'Udonis Haslem',
#   'team': 'Miami Heat',
#   'number': 40,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 106,
#   'school': 'Florida',
#   'country': 'USA'},
#  'Jaxson Hayes': {'name': 'Jaxson Hayes',
#   'team': 'New Orleans Pelicans',
#   'number': 10,
#   'position': 'C-F',
#   'height': 186.2,
#   'weight': 99,
#   'school': 'Texas-Austin',
#   'country': 'USA'},
#  'Killian Hayes': {'name': 'Killian Hayes',
#   'team': 'Detroit Pistons',
#   'number': 7,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 88,
#   'school': 'Ratiopharm Ulm',
#   'country': 'France'},
#  'Gordon Hayward': {'name': 'Gordon Hayward',
#   'team': 'Charlotte Hornets',
#   'number': 20,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 102,
#   'school': 'Butler',
#   'country': 'USA'},
#  'Juancho Hernangomez': {'name': 'Juancho Hernangomez',
#   'team': 'Minnesota Timberwolves',
#   'number': 41,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 97,
#   'school': 'Estudiantes',
#   'country': 'Spain'},
#  'Willy Hernangomez': {'name': 'Willy Hernangomez',
#   'team': 'New Orleans Pelicans',
#   'number': 9,
#   'position': 'C-F',
#   'height': 186.2,
#   'weight': 113,
#   'school': 'Cajasol Sevilla',
#   'country': 'Spain'},
#  'Tyler Herro': {'name': 'Tyler Herro',
#   'team': 'Miami Heat',
#   'number': 14,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 88,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  'Buddy Hield': {'name': 'Buddy Hield',
#   'team': 'Sacramento Kings',
#   'number': 24,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 99,
#   'school': 'Oklahoma',
#   'country': 'Bahamas'},
#  'George Hill': {'name': 'George Hill',
#   'team': 'Philadelphia 76ers',
#   'number': 33,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 85,
#   'school': 'Indiana-Purdue Indianapolis',
#   'country': 'USA'},
#  'Solomon Hill': {'name': 'Solomon Hill',
#   'team': 'Atlanta Hawks',
#   'number': 18,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 102,
#   'school': 'Arizona',
#   'country': 'USA'},
#  'Nate Hinton': {'name': 'Nate Hinton',
#   'team': 'Dallas Mavericks',
#   'number': 14,
#   'position': 'G-F',
#   'height': 198.1,
#   'weight': 95,
#   'school': 'Houston',
#   'country': 'USA'},
#  'Jaylen Hoard': {'name': 'Jaylen Hoard',
#   'team': 'Oklahoma Thunder',
#   'number': 8,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 97,
#   'school': 'Wake Forest',
#   'country': 'France'},
#  'Aaron Holiday': {'name': 'Aaron Holiday',
#   'team': 'Indiana Pacers',
#   'number': 3,
#   'position': 'G',
#   'height': 182.9,
#   'weight': 83,
#   'school': 'UCLA',
#   'country': 'USA'},
#  'Jrue Holiday': {'name': 'Jrue Holiday',
#   'team': 'Milwaukee Bucks',
#   'number': 21,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 92,
#   'school': 'UCLA',
#   'country': 'USA'},
#  'Justin Holiday': {'name': 'Justin Holiday',
#   'team': 'Indiana Pacers',
#   'number': 8,
#   'position': 'F-G',
#   'height': 201.2,
#   'weight': 81,
#   'school': 'Washington',
#   'country': 'USA'},
#  'Rondae Hollis-Jefferson': {'name': 'Rondae Hollis-Jefferson',
#   'team': 'Portland Trail Blazers',
#   'number': 2,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 98,
#   'school': 'Arizona',
#   'country': 'USA'},
#  'Richaun Holmes': {'name': 'Richaun Holmes',
#   'team': 'Sacramento Kings',
#   'number': 22,
#   'position': 'F',
#   'height': 185.9,
#   'weight': 106,
#   'school': 'Bowling Green',
#   'country': 'USA'},
#  'Caleb Homesley': {'name': 'Caleb Homesley',
#   'team': 'Washington Wizards',
#   'number': None,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 92,
#   'school': 'Liberty',
#   'country': 'USA'},
#  'Rodney Hood': {'name': 'Rodney Hood',
#   'team': 'Toronto Raptors',
#   'number': 32,
#   'position': 'G-F',
#   'height': 207.3,
#   'weight': 94,
#   'school': 'Duke',
#   'country': 'USA'},
#  'Al Horford': {'name': 'Al Horford',
#   'team': 'Boston Celtics',
#   'number': 42,
#   'position': 'C-F',
#   'height': 210.3,
#   'weight': 108,
#   'school': 'Florida',
#   'country': 'Dominican Republic'},
#  'Talen Horton-Tucker': {'name': 'Talen Horton-Tucker',
#   'team': 'Los Angeles Lackers',
#   'number': 5,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 106,
#   'school': 'Iowa State',
#   'country': 'USA'},
#  'Danuel House Jr.': {'name': 'Danuel House Jr.',
#   'team': 'Houston Rockets',
#   'number': 4,
#   'position': 'F-G',
#   'height': 201.2,
#   'weight': 99,
#   'school': 'Texas A&M',
#   'country': 'USA'},
#  'Dwight Howard': {'name': 'Dwight Howard',
#   'team': 'Philadelphia 76ers',
#   'number': 39,
#   'position': 'C-F',
#   'height': 185.9,
#   'weight': 120,
#   'school': 'SW Atlanta Christian Academy (GA)',
#   'country': 'USA'},
#  'Markus Howard': {'name': 'Markus Howard',
#   'team': 'Denver Nuggets',
#   'number': 0,
#   'position': 'G',
#   'height': 155.4,
#   'weight': 79,
#   'school': 'Marquette',
#   'country': 'USA'},
#  'Kevin Huerter': {'name': 'Kevin Huerter',
#   'team': 'Atlanta Hawks',
#   'number': 3,
#   'position': 'G-F',
#   'height': 204.2,
#   'weight': 86,
#   'school': 'Maryland',
#   'country': 'USA'},
#  'Elijah Hughes': {'name': 'Elijah Hughes',
#   'team': 'Utah Jazz',
#   'number': 33,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 97,
#   'school': 'Syracuse',
#   'country': 'USA'},
#  "De'Andre Hunter": {'name': "De'Andre Hunter",
#   'team': 'Atlanta Hawks',
#   'number': 12,
#   'position': 'F-G',
#   'height': 207.3,
#   'weight': 102,
#   'school': 'Virginia',
#   'country': 'USA'},
#  'Chandler Hutchison': {'name': 'Chandler Hutchison',
#   'team': 'Washington Wizards',
#   'number': 1,
#   'position': 'F-G',
#   'height': 201.2,
#   'weight': 95,
#   'school': 'Boise State',
#   'country': 'USA'},
#  'Serge Ibaka': {'name': 'Serge Ibaka',
#   'team': 'LA Clippers',
#   'number': 9,
#   'position': 'F',
#   'height': 185.9,
#   'weight': 106,
#   'school': 'Ricoh Manresa',
#   'country': 'Republic of the Congo'},
#  'Andre Iguodala': {'name': 'Andre Iguodala',
#   'team': 'Miami Heat',
#   'number': 28,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 97,
#   'school': 'Arizona',
#   'country': 'USA'},
#  'Ersan Ilyasova': {'name': 'Ersan Ilyasova',
#   'team': 'Utah Jazz',
#   'number': 77,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 106,
#   'school': 'FC Barcelona',
#   'country': 'Turkey'},
#  'Joe Ingles': {'name': 'Joe Ingles',
#   'team': 'Utah Jazz',
#   'number': 2,
#   'position': 'F-G',
#   'height': 207.3,
#   'weight': 99,
#   'school': 'Maccabi Tel Aviv',
#   'country': 'Australia'},
#  'Brandon Ingram': {'name': 'Brandon Ingram',
#   'team': 'New Orleans Pelicans',
#   'number': 14,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 86,
#   'school': 'Duke',
#   'country': 'USA'},
#  'Kyrie Irving': {'name': 'Kyrie Irving',
#   'team': 'Brooklyn Nets',
#   'number': 11,
#   'position': 'G',
#   'height': 189.0,
#   'weight': 88,
#   'school': 'Duke',
#   'country': 'Australia'},
#  'Jonathan Isaac': {'name': 'Jonathan Isaac',
#   'team': 'Orlando Magic',
#   'number': 1,
#   'position': 'F',
#   'height': 186.2,
#   'weight': 104,
#   'school': 'Florida State',
#   'country': 'USA'},
#  'Wes Iwundu': {'name': 'Wes Iwundu',
#   'team': 'New Orleans Pelicans',
#   'number': 4,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 88,
#   'school': 'Kansas State',
#   'country': 'USA'},
#  'Frank Jackson': {'name': 'Frank Jackson',
#   'team': 'Detroit Pistons',
#   'number': 5,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 92,
#   'school': 'Duke',
#   'country': 'USA'},
#  'Josh Jackson': {'name': 'Josh Jackson',
#   'team': 'Detroit Pistons',
#   'number': 20,
#   'position': 'G-F',
#   'height': 207.3,
#   'weight': 93,
#   'school': 'Kansas',
#   'country': 'USA'},
#  'Justin Jackson': {'name': 'Justin Jackson',
#   'team': 'Milwaukee Bucks',
#   'number': 44,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 99,
#   'school': 'North Carolina',
#   'country': 'USA'},
# ...
#  'Marcus Smart': {'name': 'Marcus Smart',
#   'team': 'Boston Celtics',
#   'number': 36,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 99,
#   'school': 'Oklahoma State',
#   'country': 'USA'},
#  'Ish Smith': {'name': 'Ish Smith',
#   'team': 'Washington Wizards',
#   'number': 14,
#   'position': 'G',
#   'height': 182.9,
#   'weight': 79,
#   'school': 'Wake Forest',
#   'country': 'USA'},
#  'Jalen Smith': {'name': 'Jalen Smith',
#   'team': 'Phoenix Suns',
#   'number': 10,
#   'position': 'F-C',
#   'height': 185.9,
#   'weight': 97,
#   'school': 'Maryland',
#   'country': 'USA'},
#  'Dennis Smith Jr.': {'name': 'Dennis Smith Jr.',
#   'team': 'Detroit Pistons',
#   'number': 0,
#   'position': 'G',
#   'height': 189.0,
#   'weight': 92,
#   'school': 'North Carolina State',
#   'country': 'USA'},
#  'Tony Snell': {'name': 'Tony Snell',
#   'team': 'Atlanta Hawks',
#   'number': 19,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 96,
#   'school': 'New Mexico',
#   'country': 'USA'},
#  'Ray Spalding': {'name': 'Ray Spalding',
#   'team': None,
#   'number': None,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 102,
#   'school': 'Louisville',
#   'country': 'USA'},
#  'Cassius Stanley': {'name': 'Cassius Stanley',
#   'team': 'Indiana Pacers',
#   'number': 2,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 86,
#   'school': 'Duke',
#   'country': 'USA'},
#  'Lamar Stevens': {'name': 'Lamar Stevens',
#   'team': 'Cleveland Cavaliers',
#   'number': 8,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 104,
#   'school': 'Penn State',
#   'country': 'USA'},
#  'Isaiah Stewart': {'name': 'Isaiah Stewart',
#   'team': 'Detroit Pistons',
#   'number': 28,
#   'position': 'F-C',
#   'height': 207.3,
#   'weight': 113,
#   'school': 'Washington',
#   'country': 'USA'},
#  'Max Strus': {'name': 'Max Strus',
#   'team': 'Miami Heat',
#   'number': 31,
#   'position': 'G-F',
#   'height': 198.1,
#   'weight': 97,
#   'school': 'DePaul',
#   'country': 'USA'},
#  'Edmond Sumner': {'name': 'Edmond Sumner',
#   'team': 'Indiana Pacers',
#   'number': 5,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 88,
#   'school': 'Xavier',
#   'country': 'USA'},
#  "Jae'Sean Tate": {'name': "Jae'Sean Tate",
#   'team': 'Houston Rockets',
#   'number': 8,
#   'position': 'F',
#   'height': 195.1,
#   'weight': 104,
#   'school': 'Ohio State',
#   'country': 'USA'},
#  'Jayson Tatum': {'name': 'Jayson Tatum',
#   'team': 'Boston Celtics',
#   'number': 0,
#   'position': 'F-G',
#   'height': 207.3,
#   'weight': 95,
#   'school': 'Duke',
#   'country': 'USA'},
#  'Jeff Teague': {'name': 'Jeff Teague',
#   'team': 'Milwaukee Bucks',
#   'number': 5,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 88,
#   'school': 'Wake Forest',
#   'country': 'USA'},
#  'Garrett Temple': {'name': 'Garrett Temple',
#   'team': 'Chicago Bulls',
#   'number': 17,
#   'position': 'G-F',
#   'height': 198.1,
#   'weight': 88,
#   'school': 'Louisiana State',
#   'country': 'USA'},
#  'Tyrell Terry': {'name': 'Tyrell Terry',
#   'team': 'Dallas Mavericks',
#   'number': 1,
#   'position': 'G',
#   'height': 189.0,
#   'weight': 72,
#   'school': 'Stanford',
#   'country': 'USA'},
#  'Daniel Theis': {'name': 'Daniel Theis',
#   'team': 'Chicago Bulls',
#   'number': 27,
#   'position': 'F-C',
#   'height': 207.3,
#   'weight': 111,
#   'school': 'Brose Bamberg',
#   'country': 'Germany'},
#  'Brodric Thomas': {'name': 'Brodric Thomas',
#   'team': 'Cleveland Cavaliers',
#   'number': 33,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 83,
#   'school': 'Truman State',
#   'country': 'USA'},
#  'Isaiah Thomas': {'name': 'Isaiah Thomas',
#   'team': None,
#   'number': None,
#   'position': 'G',
#   'height': 179.8,
#   'weight': 83,
#   'school': 'Washington',
#   'country': 'USA'},
#  'Khyri Thomas': {'name': 'Khyri Thomas',
#   'team': 'Houston Rockets',
#   'number': 13,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 95,
#   'school': 'Creighton',
#   'country': 'USA'},
#  'Matt Thomas': {'name': 'Matt Thomas',
#   'team': 'Utah Jazz',
#   'number': 21,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 86,
#   'school': 'Iowa State',
#   'country': 'USA'},
#  'Klay Thompson': {'name': 'Klay Thompson',
#   'team': 'Golden State Wariors',
#   'number': 11,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 97,
#   'school': 'Washington State',
#   'country': 'USA'},
#  'Tristan Thompson': {'name': 'Tristan Thompson',
#   'team': 'Boston Celtics',
#   'number': 13,
#   'position': 'C-F',
#   'height': 210.3,
#   'weight': 115,
#   'school': 'Texas-Austin',
#   'country': 'Canada'},
#  'Sindarius Thornwell': {'name': 'Sindarius Thornwell',
#   'team': 'Orlando Magic',
#   'number': 15,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 97,
#   'school': 'South Carolina',
#   'country': 'USA'},
#  'Matisse Thybulle': {'name': 'Matisse Thybulle',
#   'team': 'Philadelphia 76ers',
#   'number': 22,
#   'position': 'G-F',
#   'height': 198.1,
#   'weight': 91,
#   'school': 'Washington',
#   'country': 'USA'},
#  'Killian Tillie': {'name': 'Killian Tillie',
#   'team': 'Memphis Grizzlies',
#   'number': 35,
#   'position': 'F-C',
#   'height': 210.3,
#   'weight': 99,
#   'school': 'Gonzaga',
#   'country': 'France'},
#  'Xavier Tillman': {'name': 'Xavier Tillman',
#   'team': 'Memphis Grizzlies',
#   'number': 2,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 111,
#   'school': 'Michigan State',
#   'country': 'USA'},
#  'Anthony Tolliver': {'name': 'Anthony Tolliver',
#   'team': 'Philadelphia 76ers',
#   'number': 43,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 108,
#   'school': 'Creighton',
#   'country': 'USA'},
#  'Obi Toppin': {'name': 'Obi Toppin',
#   'team': 'New York Knicks',
#   'number': 1,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 99,
#   'school': 'Dayton',
#   'country': 'USA'},
#  'Juan Toscano-Anderson': {'name': 'Juan Toscano-Anderson',
#   'team': 'Golden State Wariors',
#   'number': 95,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 94,
#   'school': 'Marquette',
#   'country': 'USA'},
#  'Axel Toupane': {'name': 'Axel Toupane',
#   'team': 'Milwaukee Bucks',
#   'number': 66,
#   'position': 'G-F',
#   'height': 204.2,
#   'weight': 95,
#   'school': 'Strasbourg IG',
#   'country': 'France'},
#  'Karl-Anthony Towns': {'name': 'Karl-Anthony Towns',
#   'team': 'Minnesota Timberwolves',
#   'number': 32,
#   'position': 'C-F',
#   'height': 186.2,
#   'weight': 112,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  'Gary Trent Jr.': {'name': 'Gary Trent Jr.',
#   'team': 'Toronto Raptors',
#   'number': 33,
#   'position': 'G-F',
#   'height': 198.1,
#   'weight': 94,
#   'school': 'Duke',
#   'country': 'USA'},
#  'P.J. Tucker': {'name': 'P.J. Tucker',
#   'team': 'Milwaukee Bucks',
#   'number': 17,
#   'position': 'F',
#   'height': 198.1,
#   'weight': 111,
#   'school': 'Texas-Austin',
#   'country': 'USA'},
#  'Rayjon Tucker': {'name': 'Rayjon Tucker',
#   'team': 'Philadelphia 76ers',
#   'number': 9,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 94,
#   'school': 'Arkansas-Little Rock',
#   'country': 'USA'},
#  'Myles Turner': {'name': 'Myles Turner',
#   'team': 'Indiana Pacers',
#   'number': 33,
#   'position': 'C-F',
#   'height': 186.2,
#   'weight': 113,
#   'school': 'Texas-Austin',
#   'country': 'USA'},
#  'Jonas Valanciunas': {'name': 'Jonas Valanciunas',
#   'team': 'Memphis Grizzlies',
#   'number': 17,
#   'position': 'C',
#   'height': 186.2,
#   'weight': 120,
#   'school': 'Lietuvos rytas Vilnius',
#   'country': 'Lithuania'},
#  'Denzel Valentine': {'name': 'Denzel Valentine',
#   'team': 'Chicago Bulls',
#   'number': 45,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 99,
#   'school': 'Michigan State',
#   'country': 'USA'},
#  'Fred VanVleet': {'name': 'Fred VanVleet',
#   'team': 'Toronto Raptors',
#   'number': 23,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 89,
#   'school': 'Wichita State',
#   'country': 'USA'},
#  'Jarred Vanderbilt': {'name': 'Jarred Vanderbilt',
#   'team': 'Minnesota Timberwolves',
#   'number': 8,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 97,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  'Anderson Varejao': {'name': 'Anderson Varejao',
#   'team': None,
#   'number': None,
#   'position': 'F',
#   'height': 186.2,
#   'weight': 117,
#   'school': ' ',
#   'country': 'Brazil'},
#  'Devin Vassell': {'name': 'Devin Vassell',
#   'team': 'San Antonio Spurs',
#   'number': 24,
#   'position': 'G-F',
#   'height': 198.1,
#   'weight': 90,
#   'school': 'Florida State',
#   'country': 'USA'},
#  'Luca Vildoza': {'name': 'Luca Vildoza',
#   'team': 'New York Knicks',
#   'number': None,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 86,
#   'school': 'Baskonia',
#   'country': ''},
#  'Gabe Vincent': {'name': 'Gabe Vincent',
#   'team': 'Miami Heat',
#   'number': 2,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 90,
#   'school': 'California-Santa Barbara',
#   'country': 'USA'},
#  'Noah Vonleh': {'name': 'Noah Vonleh',
#   'team': None,
#   'number': None,
#   'position': 'F',
#   'height': 185.9,
#   'weight': 116,
#   'school': 'Indiana',
#   'country': 'USA'},
#  'Nikola Vucevic': {'name': 'Nikola Vucevic',
#   'team': 'Chicago Bulls',
#   'number': 9,
#   'position': 'C',
#   'height': 186.2,
#   'weight': 117,
#   'school': 'Southern California',
#   'country': 'Montenegro'},
#  'Dean Wade': {'name': 'Dean Wade',
#   'team': 'Cleveland Cavaliers',
#   'number': 32,
#   'position': 'F-C',
#   'height': 210.3,
#   'weight': 103,
#   'school': 'Kansas State',
#   'country': 'USA'},
#  'Moritz Wagner': {'name': 'Moritz Wagner',
#   'team': 'Orlando Magic',
#   'number': 21,
#   'position': 'F-C',
#   'height': 186.2,
#   'weight': 111,
#   'school': 'Michigan',
#   'country': 'Germany'},
#  'Kemba Walker': {'name': 'Kemba Walker',
#   'team': 'Oklahoma Thunder',
#   'number': 8,
#   'position': 'G',
#   'height': 182.9,
#   'weight': 83,
#   'school': 'Connecticut',
#   'country': 'USA'},
#  'Lonnie Walker IV': {'name': 'Lonnie Walker IV',
#   'team': 'San Antonio Spurs',
#   'number': 1,
#   'position': 'G-F',
#   'height': 195.1,
#   'weight': 92,
#   'school': 'Miami',
#   'country': 'USA'},
#  'John Wall': {'name': 'John Wall',
#   'team': 'Houston Rockets',
#   'number': 1,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 95,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  'Brad Wanamaker': {'name': 'Brad Wanamaker',
#   'team': 'Charlotte Hornets',
#   'number': 9,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 95,
#   'school': 'Pittsburgh',
#   'country': 'USA'},
#  'T.J. Warren': {'name': 'T.J. Warren',
#   'team': 'Indiana Pacers',
#   'number': 1,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 99,
#   'school': 'North Carolina State',
#   'country': 'USA'},
#  'P.J. Washington': {'name': 'P.J. Washington',
#   'team': 'Charlotte Hornets',
#   'number': 25,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 104,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  'Yuta Watanabe': {'name': 'Yuta Watanabe',
#   'team': 'Toronto Raptors',
#   'number': 18,
#   'position': 'G-F',
#   'height': 210.3,
#   'weight': 97,
#   'school': 'George Washington',
#   'country': 'Japan'},
#  'Tremont Waters': {'name': 'Tremont Waters',
#   'team': 'Boston Celtics',
#   'number': 51,
#   'position': 'G',
#   'height': 155.4,
#   'weight': 79,
#   'school': 'Louisiana State',
#   'country': 'USA'},
#  'Paul Watson': {'name': 'Paul Watson',
#   'team': 'Toronto Raptors',
#   'number': 1,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 95,
#   'school': 'Fresno State',
#   'country': 'USA'},
#  'Quinndary Weatherspoon': {'name': 'Quinndary Weatherspoon',
#   'team': 'San Antonio Spurs',
#   'number': 15,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 92,
#   'school': 'Mississippi State',
#   'country': 'USA'},
#  'Russell Westbrook': {'name': 'Russell Westbrook',
#   'team': 'Washington Wizards',
#   'number': 4,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 90,
#   'school': 'UCLA',
#   'country': 'USA'},
#  'Coby White': {'name': 'Coby White',
#   'team': 'Chicago Bulls',
#   'number': 0,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 88,
#   'school': 'North Carolina',
#   'country': 'USA'},
#  'Derrick White': {'name': 'Derrick White',
#   'team': 'San Antonio Spurs',
#   'number': 4,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 86,
#   'school': 'Colorado',
#   'country': 'USA'},
#  'Hassan Whiteside': {'name': 'Hassan Whiteside',
#   'team': 'Sacramento Kings',
#   'number': 20,
#   'position': 'C',
#   'height': 213.4,
#   'weight': 120,
#   'school': 'Marshall',
#   'country': 'USA'},
#  'Greg Whittington': {'name': 'Greg Whittington',
#   'team': None,
#   'number': None,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 95,
#   'school': 'Georgetown',
#   'country': 'USA'},
#  'Andrew Wiggins': {'name': 'Andrew Wiggins',
#   'team': 'Golden State Wariors',
#   'number': 22,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 89,
#   'school': 'Kansas',
#   'country': 'Canada'},
#  'Grant Williams': {'name': 'Grant Williams',
#   'team': 'Boston Celtics',
#   'number': 12,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 107,
#   'school': 'Tennessee',
#   'country': 'USA'},
#  'Kenrich Williams': {'name': 'Kenrich Williams',
#   'team': 'Oklahoma Thunder',
#   'number': 34,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 95,
#   'school': 'TCU',
#   'country': 'USA'},
#  'Lou Williams': {'name': 'Lou Williams',
#   'team': 'Atlanta Hawks',
#   'number': 6,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 79,
#   'school': 'South Gwinnett HS (GA)',
#   'country': 'USA'},
#  'Patrick Williams': {'name': 'Patrick Williams',
#   'team': 'Chicago Bulls',
#   'number': 44,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 97,
#   'school': 'Florida State',
#   'country': 'USA'},
#  'Robert Williams III': {'name': 'Robert Williams III',
#   'team': 'Boston Celtics',
#   'number': 44,
#   'position': 'C-F',
#   'height': 207.3,
#   'weight': 107,
#   'school': 'Texas A&M',
#   'country': 'USA'},
#  'Zion Williamson': {'name': 'Zion Williamson',
#   'team': 'New Orleans Pelicans',
#   'number': 1,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 128,
#   'school': 'Duke',
#   'country': 'USA'},
#  'D.J. Wilson': {'name': 'D.J. Wilson',
#   'team': 'Houston Rockets',
#   'number': 0,
#   'position': 'F',
#   'height': 185.9,
#   'weight': 104,
#   'school': 'Michigan',
#   'country': 'USA'},
#  'Dylan Windler': {'name': 'Dylan Windler',
#   'team': 'Cleveland Cavaliers',
#   'number': 9,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 88,
#   'school': 'Belmont',
#   'country': 'USA'},
#  'Justise Winslow': {'name': 'Justise Winslow',
#   'team': 'Memphis Grizzlies',
#   'number': 7,
#   'position': 'F-G',
#   'height': 201.2,
#   'weight': 100,
#   'school': 'Duke',
#   'country': 'USA'},
#  'Cassius Winston': {'name': 'Cassius Winston',
#   'team': 'Washington Wizards',
#   'number': 5,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 83,
#   'school': 'Michigan State',
#   'country': 'USA'},
#  'James Wiseman': {'name': 'James Wiseman',
#   'team': 'Golden State Wariors',
#   'number': 33,
#   'position': 'C',
#   'height': 213.4,
#   'weight': 108,
#   'school': 'Memphis',
#   'country': 'USA'},
#  'Christian Wood': {'name': 'Christian Wood',
#   'team': 'Houston Rockets',
#   'number': 35,
#   'position': 'F',
#   'height': 185.9,
#   'weight': 97,
#   'school': 'UNLV',
#   'country': 'USA'},
#  'Robert Woodard II': {'name': 'Robert Woodard II',
#   'team': 'Sacramento Kings',
#   'number': 13,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 106,
#   'school': 'Mississippi State',
#   'country': 'USA'},
#  'Delon Wright': {'name': 'Delon Wright',
#   'team': 'Sacramento Kings',
#   'number': 55,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 83,
#   'school': 'Utah',
#   'country': 'USA'},
#  'Thaddeus Young': {'name': 'Thaddeus Young',
#   'team': 'Chicago Bulls',
#   'number': 21,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 106,
#   'school': 'Georgia Tech',
#   'country': 'USA'},
#  'Trae Young': {'name': 'Trae Young',
#   'team': 'Atlanta Hawks',
#   'number': 11,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 81,
#   'school': 'Oklahoma',
#   'country': 'USA'},
#  'Omer Yurtseven': {'name': 'Omer Yurtseven',
#   'team': 'Miami Heat',
#   'number': 77,
#   'position': 'C',
#   'height': 213.4,
#   'weight': 124,
#   'school': 'Georgetown',
#   'country': 'Uzbekistan'},
#  'Cody Zeller': {'name': 'Cody Zeller',
#   'team': 'Charlotte Hornets',
#   'number': 40,
#   'position': 'F-C',
#   'height': 186.2,
#   'weight': 108,
#   'school': 'Indiana',
#   'country': 'USA'},
#  'Ivica Zubac': {'name': 'Ivica Zubac',
#   'team': 'LA Clippers',
#   'number': 40,
#   'position': 'C',
#   'height': 213.4,
#   'weight': 108,
#   'school': 'Mega Basket',
#   'country': 'Croatia'}}

# %%
len(players_container)
# Out:
# 546

# %% [markdown]
# Dump data to json

# %%
import json

# %%
final_json = []

for player in players_container :
    final_json.append(players_container[player])
    
final_json
# Out:
# [{'name': 'Precious Achiuwa',
#   'team': 'Miami Heat',
#   'number': 5,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 102,
#   'school': 'Memphis',
#   'country': 'Nigeria'},
#  {'name': 'Jaylen Adams',
#   'team': None,
#   'number': None,
#   'position': 'G',
#   'height': 182.9,
#   'weight': 102,
#   'school': 'St. Bonaventure',
#   'country': 'USA'},
#  {'name': 'Steven Adams',
#   'team': 'New Orleans Pelicans',
#   'number': 12,
#   'position': 'C',
#   'height': 186.2,
#   'weight': 120,
#   'school': 'Pittsburgh',
#   'country': 'New Zealand'},
#  {'name': 'Bam Adebayo',
#   'team': 'Miami Heat',
#   'number': 13,
#   'position': 'C-F',
#   'height': 210.3,
#   'weight': 115,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  {'name': 'LaMarcus Aldridge',
#   'team': None,
#   'number': None,
#   'position': 'C-F',
#   'height': 186.2,
#   'weight': 113,
#   'school': 'Texas-Austin',
#   'country': 'USA'},
#  {'name': 'Ty-Shon Alexander',
#   'team': 'Phoenix Suns',
#   'number': 0,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 88,
#   'school': 'Creighton',
#   'country': 'USA'},
#  {'name': 'Nickeil Alexander-Walker',
#   'team': 'New Orleans Pelicans',
#   'number': 6,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 92,
#   'school': 'Virginia Tech',
#   'country': 'Canada'},
#  {'name': 'Grayson Allen',
#   'team': 'Memphis Grizzlies',
#   'number': 3,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 89,
#   'school': 'Duke',
#   'country': 'USA'},
#  {'name': 'Jarrett Allen',
#   'team': 'Cleveland Cavaliers',
#   'number': 31,
#   'position': 'C',
#   'height': 186.2,
#   'weight': 110,
#   'school': 'Texas-Austin',
#   'country': 'USA'},
#  {'name': 'Al-Farouq Aminu',
#   'team': 'Chicago Bulls',
#   'number': 5,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 99,
#   'school': 'Wake Forest',
#   'country': 'USA'},
#  {'name': 'Kyle Anderson',
#   'team': 'Memphis Grizzlies',
#   'number': 1,
#   'position': 'F-G',
#   'height': 210.3,
#   'weight': 104,
#   'school': 'UCLA',
#   'country': 'USA'},
#  {'name': 'Giannis Antetokounmpo',
#   'team': 'Milwaukee Bucks',
#   'number': 34,
#   'position': 'F',
#   'height': 186.2,
#   'weight': 109,
#   'school': 'Filathlitikos',
#   'country': 'Greece'},
#  {'name': 'Kostas Antetokounmpo',
#   'team': 'Los Angeles Lackers',
#   'number': 37,
#   'position': 'F',
#   'height': 185.9,
#   'weight': 90,
#   'school': 'Dayton',
#   'country': 'Greece'},
#  {'name': 'Thanasis Antetokounmpo',
#   'team': 'Milwaukee Bucks',
#   'number': 43,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 99,
#   'school': 'Panathinaikos',
#   'country': 'Greece'},
#  {'name': 'Carmelo Anthony',
#   'team': 'Portland Trail Blazers',
#   'number': 0,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 107,
#   'school': 'Syracuse',
#   'country': 'USA'},
#  {'name': 'Cole Anthony',
#   'team': 'Orlando Magic',
#   'number': 50,
#   'position': 'G',
#   'height': 189.0,
#   'weight': 83,
#   'school': 'North Carolina',
#   'country': 'USA'},
#  {'name': 'OG Anunoby',
#   'team': 'Toronto Raptors',
#   'number': 3,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 105,
#   'school': 'Indiana',
#   'country': 'United Kingdom'},
#  {'name': 'Ryan Arcidiacono',
#   'team': 'Chicago Bulls',
#   'number': 51,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 88,
#   'school': 'Villanova',
#   'country': 'USA'},
#  {'name': 'Trevor Ariza',
#   'team': 'Miami Heat',
#   'number': 8,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 97,
#   'school': 'UCLA',
#   'country': 'USA'},
#  {'name': 'D.J. Augustin',
#   'team': 'Houston Rockets',
#   'number': 14,
#   'position': 'G',
#   'height': 155.8,
#   'weight': 82,
#   'school': 'Texas-Austin',
#   'country': 'USA'},
#  {'name': 'Deni Avdija',
#   'team': 'Washington Wizards',
#   'number': 9,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 95,
#   'school': 'Maccabi Tel Aviv',
#   'country': 'Israel'},
#  {'name': 'Deandre Ayton',
#   'team': 'Phoenix Suns',
#   'number': 22,
#   'position': 'C',
#   'height': 186.2,
#   'weight': 113,
#   'school': 'Arizona',
#   'country': 'Bahamas'},
#  {'name': 'Udoka Azubuike',
#   'team': 'Utah Jazz',
#   'number': 20,
#   'position': 'C-F',
#   'height': 185.9,
#   'weight': 126,
#   'school': 'Kansas',
#   'country': 'Nigeria'},
#  {'name': 'Dwayne Bacon',
#   'team': 'Orlando Magic',
#   'number': 8,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 100,
#   'school': 'Florida State',
#   'country': 'USA'},
#  {'name': 'Marvin Bagley III',
#   'team': 'Sacramento Kings',
#   'number': 35,
#   'position': 'F',
#   'height': 186.2,
#   'weight': 106,
#   'school': 'Duke',
#   'country': 'USA'},
#  {'name': 'LaMelo Ball',
#   'team': 'Charlotte Hornets',
#   'number': 2,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 81,
#   'school': 'Illawarra',
#   'country': 'USA'},
#  {'name': 'Lonzo Ball',
#   'team': 'New Orleans Pelicans',
#   'number': 2,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 86,
#   'school': 'UCLA',
#   'country': 'USA'},
#  {'name': 'Mo Bamba',
#   'team': 'Orlando Magic',
#   'number': 5,
#   'position': 'C',
#   'height': 213.4,
#   'weight': 104,
#   'school': 'Texas-Austin',
#   'country': 'USA'},
#  {'name': 'Desmond Bane',
#   'team': 'Memphis Grizzlies',
#   'number': 22,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 97,
#   'school': 'TCU',
#   'country': 'USA'},
#  {'name': 'Harrison Barnes',
#   'team': 'Sacramento Kings',
#   'number': 40,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 102,
#   'school': 'North Carolina',
#   'country': 'USA'},
#  {'name': 'RJ Barrett',
#   'team': 'New York Knicks',
#   'number': 9,
#   'position': 'F-G',
#   'height': 201.2,
#   'weight': 97,
#   'school': 'Duke',
#   'country': 'Canada'},
#  {'name': 'Will Barton',
#   'team': 'Denver Nuggets',
#   'number': 5,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 82,
#   'school': 'Memphis',
#   'country': 'USA'},
#  {'name': 'Keita Bates-Diop',
#   'team': 'San Antonio Spurs',
#   'number': 31,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 103,
#   'school': 'Ohio State',
#   'country': 'USA'},
#  {'name': 'Nicolas Batum',
#   'team': 'LA Clippers',
#   'number': 33,
#   'position': 'G-F',
#   'height': 207.3,
#   'weight': 104,
#   'school': 'Le Mans',
#   'country': 'France'},
#  {'name': 'Aron Baynes',
#   'team': 'Toronto Raptors',
#   'number': 46,
#   'position': 'C-F',
#   'height': 185.9,
#   'weight': 117,
#   'school': 'Washington State',
#   'country': 'Australia'},
#  {'name': 'Kent Bazemore',
#   'team': 'Golden State Wariors',
#   'number': 26,
#   'position': 'G-F',
#   'height': 195.1,
#   'weight': 88,
#   'school': 'Old Dominion',
#   'country': 'USA'},
#  {'name': 'Darius Bazley',
#   'team': 'Oklahoma Thunder',
#   'number': 7,
#   'position': 'F-G',
#   'height': 207.3,
#   'weight': 94,
#   'school': 'Princeton HS (OH)',
#   'country': 'USA'},
#  {'name': 'Bradley Beal',
#   'team': 'Washington Wizards',
#   'number': 3,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 93,
#   'school': 'Florida',
#   'country': 'USA'},
#  {'name': 'Malik Beasley',
#   'team': 'Minnesota Timberwolves',
#   'number': 5,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 84,
#   'school': 'Florida State',
#   'country': 'USA'},
#  {'name': 'Jordan Bell',
#   'team': 'Golden State Wariors',
#   'number': 7,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 97,
#   'school': 'Oregon',
#   'country': 'USA'},
#  {'name': "DeAndre' Bembry",
#   'team': 'Toronto Raptors',
#   'number': 95,
#   'position': 'G-F',
#   'height': 198.1,
#   'weight': 95,
#   'school': "St. Joseph's (PA)",
#   'country': 'USA'},
#  {'name': 'Davis Bertans',
#   'team': 'Washington Wizards',
#   'number': 42,
#   'position': 'F',
#   'height': 185.9,
#   'weight': 102,
#   'school': 'Baskonia',
#   'country': 'Latvia'},
#  {'name': 'Patrick Beverley',
#   'team': 'LA Clippers',
#   'number': 21,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 81,
#   'school': 'Arkansas',
#   'country': 'USA'},
#  {'name': 'Saddiq Bey',
#   'team': 'Detroit Pistons',
#   'number': 41,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 97,
#   'school': 'Villanova',
#   'country': 'USA'},
#  {'name': 'Tyler Bey',
#   'team': 'Dallas Mavericks',
#   'number': 2,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 97,
#   'school': 'Colorado',
#   'country': 'USA'},
#  {'name': 'Khem Birch',
#   'team': 'Toronto Raptors',
#   'number': 24,
#   'position': 'C',
#   'height': 210.3,
#   'weight': 105,
#   'school': 'UNLV',
#   'country': 'Canada'},
#  {'name': 'Goga Bitadze',
#   'team': 'Indiana Pacers',
#   'number': 88,
#   'position': 'C-F',
#   'height': 186.2,
#   'weight': 113,
#   'school': 'Mega Basket',
#   'country': 'Georgia'},
#  {'name': 'Bismack Biyombo',
#   'team': 'Charlotte Hornets',
#   'number': 8,
#   'position': 'C',
#   'height': 207.3,
#   'weight': 115,
#   'school': 'Baloncesto Fuenlabrada',
#   'country': 'DRC'},
#  {'name': 'Nemanja Bjelica',
#   'team': 'Miami Heat',
#   'number': 70,
#   'position': 'F',
#   'height': 185.9,
#   'weight': 106,
#   'school': 'Fenerbahce',
#   'country': 'Serbia'},
#  {'name': 'Eric Bledsoe',
#   'team': 'New Orleans Pelicans',
#   'number': 5,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 97,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  {'name': 'Keljin Blevins',
#   'team': 'Portland Trail Blazers',
#   'number': 21,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 90,
#   'school': 'Montana State',
#   'country': 'USA'},
#  {'name': 'Bogdan Bogdanovic',
#   'team': 'Atlanta Hawks',
#   'number': 13,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 99,
#   'school': 'Fenerbahce',
#   'country': 'Serbia'},
#  {'name': 'Bojan Bogdanovic',
#   'team': 'Utah Jazz',
#   'number': 44,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 102,
#   'school': 'Fenerbahce',
#   'country': 'Croatia'},
#  {'name': 'Bol Bol',
#   'team': 'Denver Nuggets',
#   'number': 10,
#   'position': 'C-F',
#   'height': 219.5,
#   'weight': 99,
#   'school': 'Oregon',
#   'country': 'Sudan'},
#  {'name': 'Marques Bolden',
#   'team': None,
#   'number': None,
#   'position': 'C',
#   'height': 185.9,
#   'weight': 112,
#   'school': 'Duke',
#   'country': 'USA'},
#  {'name': 'Jordan Bone',
#   'team': None,
#   'number': None,
#   'position': 'G',
#   'height': 189.0,
#   'weight': 81,
#   'school': 'Tennessee',
#   'country': 'USA'},
#  {'name': 'Isaac Bonga',
#   'team': 'Washington Wizards',
#   'number': 17,
#   'position': 'G',
#   'height': 207.3,
#   'weight': 81,
#   'school': 'Skyliners Frankfurt',
#   'country': 'Germany'},
#  {'name': 'Devin Booker',
#   'team': 'Phoenix Suns',
#   'number': 1,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 93,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  {'name': 'Chris Boucher',
#   'team': 'Toronto Raptors',
#   'number': 25,
#   'position': 'F-C',
#   'height': 210.3,
#   'weight': 90,
#   'school': 'Oregon',
#   'country': 'Saint Lucia'},
#  {'name': 'Brian Bowen II',
#   'team': None,
#   'number': None,
#   'position': 'F-G',
#   'height': 201.2,
#   'weight': 86,
#   'school': ' ',
#   'country': 'USA'},
#  {'name': 'Avery Bradley',
#   'team': 'Houston Rockets',
#   'number': 9,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 81,
#   'school': 'Texas-Austin',
#   'country': 'USA'},
#  {'name': 'Tony Bradley',
#   'team': 'Oklahoma Thunder',
#   'number': 13,
#   'position': 'C-F',
#   'height': 185.9,
#   'weight': 112,
#   'school': 'North Carolina',
#   'country': 'USA'},
#  {'name': 'Jarrell Brantley',
#   'team': 'Utah Jazz',
#   'number': 5,
#   'position': 'F',
#   'height': 198.1,
#   'weight': 113,
#   'school': 'College of Charleston',
#   'country': 'USA'},
#  {'name': 'Ignas Brazdeikis',
#   'team': 'Orlando Magic',
#   'number': 17,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 100,
#   'school': 'Michigan',
#   'country': 'Canada'},
#  {'name': 'Mikal Bridges',
#   'team': 'Phoenix Suns',
#   'number': 25,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 94,
#   'school': 'Villanova',
#   'country': 'USA'},
#  {'name': 'Miles Bridges',
#   'team': 'Charlotte Hornets',
#   'number': 0,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 102,
#   'school': 'Michigan State',
#   'country': 'USA'},
#  {'name': 'Amida Brimah',
#   'team': 'Indiana Pacers',
#   'number': 37,
#   'position': 'C',
#   'height': 185.9,
#   'weight': 104,
#   'school': 'Connecticut',
#   'country': 'USA'},
#  {'name': 'Oshae Brissett',
#   'team': 'Indiana Pacers',
#   'number': 12,
#   'position': 'F-G',
#   'height': 204.2,
#   'weight': 95,
#   'school': 'Syracuse',
#   'country': 'Canada'},
#  {'name': 'Malcolm Brogdon',
#   'team': 'Indiana Pacers',
#   'number': 7,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 103,
#   'school': 'Virginia',
#   'country': 'USA'},
#  {'name': 'Armoni Brooks',
#   'team': 'Houston Rockets',
#   'number': 7,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 88,
#   'school': 'Houston',
#   'country': 'USA'},
#  {'name': 'Dillon Brooks',
#   'team': 'Memphis Grizzlies',
#   'number': 24,
#   'position': 'G-F',
#   'height': 204.2,
#   'weight': 102,
#   'school': 'Oregon',
#   'country': 'Canada'},
#  {'name': 'Bruce Brown',
#   'team': 'Brooklyn Nets',
#   'number': 1,
#   'position': 'G-F',
#   'height': 195.1,
#   'weight': 91,
#   'school': 'Miami',
#   'country': 'USA'},
#  {'name': 'Jaylen Brown',
#   'team': 'Boston Celtics',
#   'number': 7,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 101,
#   'school': 'California',
#   'country': 'USA'},
#  {'name': 'Moses Brown',
#   'team': 'Boston Celtics',
#   'number': 9,
#   'position': 'C',
#   'height': 219.5,
#   'weight': 111,
#   'school': 'UCLA',
#   'country': 'USA'},
#  {'name': 'Sterling Brown',
#   'team': 'Houston Rockets',
#   'number': 0,
#   'position': 'G-F',
#   'height': 198.1,
#   'weight': 99,
#   'school': 'Southern Methodist',
#   'country': 'USA'},
#  {'name': 'Charlie Brown Jr.',
#   'team': 'Oklahoma Thunder',
#   'number': 44,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 90,
#   'school': "St. Joseph's (PA)",
#   'country': 'USA'},
#  {'name': 'Troy Brown Jr.',
#   'team': 'Chicago Bulls',
#   'number': 7,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 97,
#   'school': 'Oregon',
#   'country': 'USA'},
#  {'name': 'Jalen Brunson',
#   'team': 'Dallas Mavericks',
#   'number': 13,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 86,
#   'school': 'Villanova',
#   'country': 'USA'},
#  {'name': 'Elijah Bryant',
#   'team': 'Milwaukee Bucks',
#   'number': None,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 95,
#   'school': 'Brigham Young',
#   'country': 'USA'},
#  {'name': 'Thomas Bryant',
#   'team': 'Washington Wizards',
#   'number': 13,
#   'position': 'C-F',
#   'height': 185.9,
#   'weight': 112,
#   'school': 'Indiana',
#   'country': 'USA'},
#  {'name': 'Reggie Bullock',
#   'team': 'New York Knicks',
#   'number': 25,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 92,
#   'school': 'North Carolina',
#   'country': 'USA'},
#  {'name': 'Trey Burke',
#   'team': 'Dallas Mavericks',
#   'number': 3,
#   'position': 'G',
#   'height': 182.9,
#   'weight': 83,
#   'school': 'Michigan',
#   'country': 'USA'},
#  {'name': 'Alec Burks',
#   'team': 'New York Knicks',
#   'number': 18,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 97,
#   'school': 'Colorado',
#   'country': 'USA'},
#  {'name': 'Jimmy Butler',
#   'team': 'Miami Heat',
#   'number': 22,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 104,
#   'school': 'Marquette',
#   'country': 'USA'},
#  {'name': 'Bruno Caboclo',
#   'team': None,
#   'number': None,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 98,
#   'school': '',
#   'country': 'Brazil'},
#  {'name': 'Devontae Cacok',
#   'team': 'Los Angeles Lackers',
#   'number': 12,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 108,
#   'school': 'North Carolina-Wilmington',
#   'country': 'USA'},
#  {'name': 'Kentavious Caldwell-Pope',
#   'team': 'Los Angeles Lackers',
#   'number': 1,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 92,
#   'school': 'Georgia',
#   'country': 'USA'},
#  {'name': 'Facundo Campazzo',
#   'team': 'Denver Nuggets',
#   'number': 7,
#   'position': 'G',
#   'height': 155.4,
#   'weight': 88,
#   'school': 'Murcia',
#   'country': 'Argentina'},
#  {'name': 'Vlatko Cancar',
#   'team': 'Denver Nuggets',
#   'number': 31,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 107,
#   'school': 'San Pablo Burgos',
#   'country': 'Slovenia'},
#  {'name': 'Devin Cannady',
#   'team': None,
#   'number': None,
#   'position': 'G',
#   'height': 189.0,
#   'weight': 82,
#   'school': 'Princeton',
#   'country': 'USA'},
#  {'name': 'Clint Capela',
#   'team': 'Atlanta Hawks',
#   'number': 15,
#   'position': 'C',
#   'height': 185.9,
#   'weight': 108,
#   'school': 'Elan Chalon',
#   'country': 'Switzerland'},
#  {'name': 'Vernon Carey Jr.',
#   'team': 'Charlotte Hornets',
#   'number': 22,
#   'position': 'F-C',
#   'height': 210.3,
#   'weight': 122,
#   'school': 'Duke',
#   'country': 'USA'},
#  {'name': 'Jevon Carter',
#   'team': 'Phoenix Suns',
#   'number': 4,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 90,
#   'school': 'West Virginia',
#   'country': 'USA'},
#  {'name': 'Wendell Carter Jr.',
#   'team': 'Orlando Magic',
#   'number': 34,
#   'position': 'C-F',
#   'height': 185.9,
#   'weight': 122,
#   'school': 'Duke',
#   'country': 'USA'},
#  {'name': 'Michael Carter-Williams',
#   'team': 'Orlando Magic',
#   'number': 7,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 86,
#   'school': 'Syracuse',
#   'country': 'USA'},
#  {'name': 'Alex Caruso',
#   'team': 'Los Angeles Lackers',
#   'number': 4,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 84,
#   'school': 'Texas A&M',
#   'country': 'USA'},
#  {'name': 'Willie Cauley-Stein',
#   'team': 'Dallas Mavericks',
#   'number': 33,
#   'position': 'C',
#   'height': 213.4,
#   'weight': 108,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  {'name': 'Chris Chiozza',
#   'team': 'Brooklyn Nets',
#   'number': 4,
#   'position': 'G',
#   'height': 155.8,
#   'weight': 79,
#   'school': 'Florida',
#   'country': 'USA'},
#  {'name': 'Marquese Chriss',
#   'team': None,
#   'number': None,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 108,
#   'school': 'Washington',
#   'country': 'USA'},
#  {'name': 'Gary Clark',
#   'team': 'Philadelphia 76ers',
#   'number': 12,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 102,
#   'school': 'Cincinnati',
#   'country': 'USA'},
#  {'name': 'Brandon Clarke',
#   'team': 'Memphis Grizzlies',
#   'number': 15,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 97,
#   'school': 'Gonzaga',
#   'country': 'Canada'},
#  {'name': 'Jordan Clarkson',
#   'team': 'Utah Jazz',
#   'number': 0,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 87,
#   'school': 'Missouri',
#   'country': 'USA'},
#  {'name': 'Nicolas Claxton',
#   'team': 'Brooklyn Nets',
#   'number': 33,
#   'position': 'F-C',
#   'height': 186.2,
#   'weight': 97,
#   'school': 'Georgia',
#   'country': 'USA'},
#  {'name': 'Amir Coffey',
#   'team': 'LA Clippers',
#   'number': 7,
#   'position': 'G-F',
#   'height': 204.2,
#   'weight': 95,
#   'school': 'Minnesota',
#   'country': 'USA'},
#  {'name': 'John Collins',
#   'team': 'Atlanta Hawks',
#   'number': 20,
#   'position': 'F-C',
#   'height': 210.3,
#   'weight': 106,
#   'school': 'Wake Forest',
#   'country': 'USA'},
#  {'name': 'Zach Collins',
#   'team': 'Portland Trail Blazers',
#   'number': 33,
#   'position': 'F-C',
#   'height': 186.2,
#   'weight': 113,
#   'school': 'Gonzaga',
#   'country': 'USA'},
#  {'name': 'Mike Conley',
#   'team': 'Utah Jazz',
#   'number': 10,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 79,
#   'school': 'Ohio State',
#   'country': 'USA'},
#  {'name': 'Pat Connaughton',
#   'team': 'Milwaukee Bucks',
#   'number': 24,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 94,
#   'school': 'Notre Dame',
#   'country': 'USA'},
#  {'name': 'Quinn Cook',
#   'team': None,
#   'number': None,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 81,
#   'school': 'Duke',
#   'country': 'USA'},
#  {'name': 'Tyler Cook',
#   'team': 'Detroit Pistons',
#   'number': 25,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 115,
#   'school': 'Iowa',
#   'country': 'USA'},
#  {'name': 'DeMarcus Cousins',
#   'team': 'LA Clippers',
#   'number': 15,
#   'position': 'C',
#   'height': 185.9,
#   'weight': 122,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  {'name': 'Robert Covington',
#   'team': 'Portland Trail Blazers',
#   'number': 23,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 94,
#   'school': 'Tennessee State',
#   'country': 'USA'},
#  {'name': 'Torrey Craig',
#   'team': 'Phoenix Suns',
#   'number': 12,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 100,
#   'school': 'South Carolina Upstate',
#   'country': 'USA'},
#  {'name': 'Jae Crowder',
#   'team': 'Phoenix Suns',
#   'number': 99,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 106,
#   'school': 'Marquette',
#   'country': 'USA'},
#  {'name': 'Jarrett Culver',
#   'team': 'Minnesota Timberwolves',
#   'number': 23,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 88,
#   'school': 'Texas Tech',
#   'country': 'USA'},
#  {'name': 'Seth Curry',
#   'team': 'Philadelphia 76ers',
#   'number': 31,
#   'position': 'G',
#   'height': 189.0,
#   'weight': 83,
#   'school': 'Duke',
#   'country': 'USA'},
#  {'name': 'Stephen Curry',
#   'team': 'Golden State Wariors',
#   'number': 30,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 83,
#   'school': 'Davidson',
#   'country': 'USA'},
#  {'name': 'Nate Darling',
#   'team': 'Charlotte Hornets',
#   'number': 30,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 90,
#   'school': 'Delaware',
#   'country': 'Canada'},
#  {'name': 'Anthony Davis',
#   'team': 'Los Angeles Lackers',
#   'number': 3,
#   'position': 'F-C',
#   'height': 185.9,
#   'weight': 114,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  {'name': 'Ed Davis',
#   'team': 'Minnesota Timberwolves',
#   'number': 17,
#   'position': 'C-F',
#   'height': 210.3,
#   'weight': 98,
#   'school': 'North Carolina',
#   'country': 'USA'},
#  {'name': 'Terence Davis',
#   'team': 'Sacramento Kings',
#   'number': 9,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 91,
#   'school': 'Mississippi',
#   'country': 'USA'},
#  {'name': 'DeMar DeRozan',
#   'team': 'San Antonio Spurs',
#   'number': 10,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 99,
#   'school': 'Southern California',
#   'country': 'USA'},
#  {'name': 'Gabriel Deck',
#   'team': 'Oklahoma Thunder',
#   'number': 6,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 104,
#   'school': 'Real Madrid',
#   'country': 'Argentina'},
#  {'name': 'Dewayne Dedmon',
#   'team': 'Miami Heat',
#   'number': 21,
#   'position': 'C',
#   'height': 213.4,
#   'weight': 111,
#   'school': 'Southern California',
#   'country': 'USA'},
#  {'name': 'Matthew Dellavedova',
#   'team': 'Cleveland Cavaliers',
#   'number': 18,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 90,
#   'school': "St.Mary's College of California",
#   'country': 'Australia'},
#  {'name': 'Donte DiVincenzo',
#   'team': 'Milwaukee Bucks',
#   'number': 0,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 92,
#   'school': 'Villanova',
#   'country': 'USA'},
#  {'name': 'Mamadi Diakite',
#   'team': 'Milwaukee Bucks',
#   'number': 25,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 103,
#   'school': 'Virginia',
#   'country': 'Guinea'},
#  {'name': 'Hamidou Diallo',
#   'team': 'Detroit Pistons',
#   'number': 6,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 91,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  {'name': 'Gorgui Dieng',
#   'team': 'San Antonio Spurs',
#   'number': 7,
#   'position': 'C',
#   'height': 185.9,
#   'weight': 114,
#   'school': 'Louisville',
#   'country': 'Senegal'},
#  {'name': 'Spencer Dinwiddie',
#   'team': 'Brooklyn Nets',
#   'number': 26,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 97,
#   'school': 'Colorado',
#   'country': 'USA'},
#  {'name': 'Luka Doncic',
#   'team': 'Dallas Mavericks',
#   'number': 77,
#   'position': 'F-G',
#   'height': 204.2,
#   'weight': 104,
#   'school': 'Real Madrid',
#   'country': 'Slovenia'},
#  {'name': 'Luguentz Dort',
#   'team': 'Oklahoma Thunder',
#   'number': 5,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 97,
#   'school': 'Arizona State',
#   'country': 'Canada'},
#  {'name': 'Damyean Dotson',
#   'team': 'Cleveland Cavaliers',
#   'number': 21,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 95,
#   'school': 'Houston',
#   'country': 'USA'},
#  {'name': 'Devon Dotson',
#   'team': 'Chicago Bulls',
#   'number': 3,
#   'position': 'G',
#   'height': 189.0,
#   'weight': 83,
#   'school': 'Kansas',
#   'country': 'USA'},
#  {'name': 'Sekou Doumbouya',
#   'team': 'Detroit Pistons',
#   'number': 45,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 104,
#   'school': 'Limoges',
#   'country': 'France'},
#  {'name': 'PJ Dozier',
#   'team': 'Denver Nuggets',
#   'number': 35,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 92,
#   'school': 'South Carolina',
#   'country': 'USA'},
#  {'name': 'Goran Dragic',
#   'team': 'Miami Heat',
#   'number': 7,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 86,
#   'school': 'Union Olimpija',
#   'country': 'Slovenia'},
#  {'name': 'Andre Drummond',
#   'team': 'Los Angeles Lackers',
#   'number': 2,
#   'position': 'C',
#   'height': 185.9,
#   'weight': 126,
#   'school': 'Connecticut',
#   'country': 'USA'},
#  {'name': 'Jared Dudley',
#   'team': 'Los Angeles Lackers',
#   'number': 10,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 107,
#   'school': 'Boston College',
#   'country': 'USA'},
#  {'name': 'Kris Dunn',
#   'team': 'Atlanta Hawks',
#   'number': 32,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 92,
#   'school': 'Providence',
#   'country': 'USA'},
#  {'name': 'Kevin Durant',
#   'team': 'Brooklyn Nets',
#   'number': 7,
#   'position': 'F',
#   'height': 185.9,
#   'weight': 108,
#   'school': 'Texas-Austin',
#   'country': 'USA'},
#  {'name': 'Anthony Edwards',
#   'team': 'Minnesota Timberwolves',
#   'number': 1,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 102,
#   'school': 'Georgia',
#   'country': 'USA'},
#  {'name': 'Carsen Edwards',
#   'team': 'Boston Celtics',
#   'number': 4,
#   'position': 'G',
#   'height': 155.8,
#   'weight': 90,
#   'school': 'Purdue',
#   'country': 'USA'},
#  {'name': 'CJ Elleby',
#   'team': 'Portland Trail Blazers',
#   'number': 16,
#   'position': 'F-G',
#   'height': 201.2,
#   'weight': 90,
#   'school': 'Washington State',
#   'country': 'USA'},
#  {'name': 'Henry Ellenson',
#   'team': None,
#   'number': None,
#   'position': 'F-C',
#   'height': 185.9,
#   'weight': 108,
#   'school': 'Marquette',
#   'country': 'USA'},
#  {'name': 'Wayne Ellington',
#   'team': 'Detroit Pistons',
#   'number': 8,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 93,
#   'school': 'North Carolina',
#   'country': 'USA'},
#  {'name': 'Joel Embiid',
#   'team': 'Philadelphia 76ers',
#   'number': 21,
#   'position': 'C-F',
#   'height': 213.4,
#   'weight': 126,
#   'school': 'Kansas',
#   'country': 'Cameroon'},
#  {'name': 'James Ennis III',
#   'team': 'Orlando Magic',
#   'number': 11,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 97,
#   'school': 'California State-Long Beach',
#   'country': 'USA'},
#  {'name': 'Drew Eubanks',
#   'team': 'San Antonio Spurs',
#   'number': 14,
#   'position': 'F-C',
#   'height': 210.3,
#   'weight': 111,
#   'school': 'Oregon State',
#   'country': 'USA'},
#  {'name': 'Dante Exum',
#   'team': 'Houston Rockets',
#   'number': 5,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 97,
#   'school': 'Australian Institute of Sport',
#   'country': 'Australia'},
#  {'name': 'Tacko Fall',
#   'team': 'Boston Celtics',
#   'number': 99,
#   'position': 'C',
#   'height': 228.6,
#   'weight': 141,
#   'school': 'Central Florida',
#   'country': 'Senegal'},
#  {'name': 'Derrick Favors',
#   'team': 'Utah Jazz',
#   'number': 15,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 120,
#   'school': 'Georgia Tech',
#   'country': 'USA'},
#  {'name': 'Cristiano Felicio',
#   'team': 'Chicago Bulls',
#   'number': 6,
#   'position': 'F-C',
#   'height': 186.2,
#   'weight': 122,
#   'school': 'Flamengo',
#   'country': 'Brazil'},
#  {'name': 'Terrance Ferguson',
#   'team': None,
#   'number': None,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 86,
#   'school': '',
#   'country': 'USA'},
#  {'name': 'Bruno Fernando',
#   'team': 'Atlanta Hawks',
#   'number': 24,
#   'position': 'F-C',
#   'height': 210.3,
#   'weight': 108,
#   'school': 'Maryland',
#   'country': 'Angola'},
#  {'name': 'Yogi Ferrell',
#   'team': 'LA Clippers',
#   'number': 11,
#   'position': 'G',
#   'height': 182.9,
#   'weight': 80,
#   'school': 'Indiana',
#   'country': 'USA'},
#  {'name': 'Dorian Finney-Smith',
#   'team': 'Dallas Mavericks',
#   'number': 10,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 99,
#   'school': 'Florida',
#   'country': 'USA'},
#  {'name': 'Malik Fitts',
#   'team': None,
#   'number': None,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 104,
#   'school': '-',
#   'country': 'USA'},
#  {'name': 'Malachi Flynn',
#   'team': 'Toronto Raptors',
#   'number': 8,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 79,
#   'school': 'San Diego State',
#   'country': 'USA'},
#  {'name': 'Bryn Forbes',
#   'team': 'Milwaukee Bucks',
#   'number': 7,
#   'position': 'G',
#   'height': 189.0,
#   'weight': 92,
#   'school': 'Michigan State',
#   'country': 'USA'},
#  {'name': 'Trent Forrest',
#   'team': 'Utah Jazz',
#   'number': 3,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 95,
#   'school': 'Florida State',
#   'country': 'USA'},
#  {'name': 'Evan Fournier',
#   'team': 'Boston Celtics',
#   'number': 94,
#   'position': 'G-F',
#   'height': 204.2,
#   'weight': 92,
#   'school': 'Poitiers Basket 86',
#   'country': 'France'},
#  {'name': "De'Aaron Fox",
#   'team': 'Sacramento Kings',
#   'number': 5,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 83,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  {'name': 'Robert Franks',
#   'team': None,
#   'number': None,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 102,
#   'school': 'Washington State',
#   'country': 'USA'},
#  {'name': 'Tim Frazier',
#   'team': 'Memphis Grizzlies',
#   'number': 10,
#   'position': 'G',
#   'height': 182.9,
#   'weight': 77,
#   'school': 'Penn State',
#   'country': 'USA'},
#  {'name': 'Markelle Fultz',
#   'team': 'Orlando Magic',
#   'number': 20,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 94,
#   'school': 'Washington',
#   'country': 'USA'},
#  {'name': 'Wenyen Gabriel',
#   'team': 'New Orleans Pelicans',
#   'number': 32,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 92,
#   'school': 'Kentucky',
#   'country': 'South Sudan'},
#  {'name': 'Daniel Gafford',
#   'team': 'Washington Wizards',
#   'number': 21,
#   'position': 'F-C',
#   'height': 185.9,
#   'weight': 106,
#   'school': 'Arkansas',
#   'country': 'USA'},
#  {'name': 'Danilo Gallinari',
#   'team': 'Atlanta Hawks',
#   'number': 8,
#   'position': 'F',
#   'height': 185.9,
#   'weight': 105,
#   'school': 'Olimpia Milano',
#   'country': 'Italy'},
#  {'name': 'Langston Galloway',
#   'team': 'Phoenix Suns',
#   'number': 2,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 90,
#   'school': "St. Joseph's (PA)",
#   'country': 'USA'},
#  {'name': 'Darius Garland',
#   'team': 'Cleveland Cavaliers',
#   'number': 10,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 87,
#   'school': 'Vanderbilt',
#   'country': 'USA'},
#  {'name': 'Marc Gasol',
#   'team': 'Los Angeles Lackers',
#   'number': 14,
#   'position': 'C',
#   'height': 186.2,
#   'weight': 115,
#   'school': 'FC Barcelona',
#   'country': 'Spain'},
#  {'name': 'Rudy Gay',
#   'team': 'San Antonio Spurs',
#   'number': 22,
#   'position': 'F-G',
#   'height': 207.3,
#   'weight': 113,
#   'school': 'Connecticut',
#   'country': 'USA'},
#  {'name': 'Paul George',
#   'team': 'LA Clippers',
#   'number': 13,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 99,
#   'school': 'Fresno State',
#   'country': 'USA'},
#  {'name': 'Taj Gibson',
#   'team': 'New York Knicks',
#   'number': 67,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 105,
#   'school': 'Southern California',
#   'country': 'USA'},
#  {'name': 'Harry Giles III',
#   'team': 'Portland Trail Blazers',
#   'number': 4,
#   'position': 'F-C',
#   'height': 186.2,
#   'weight': 108,
#   'school': 'Duke',
#   'country': 'USA'},
#  {'name': 'Shai Gilgeous-Alexander',
#   'team': 'Oklahoma Thunder',
#   'number': 2,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 81,
#   'school': 'Kentucky',
#   'country': 'Canada'},
#  {'name': 'Anthony Gill',
#   'team': 'Washington Wizards',
#   'number': 16,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 104,
#   'school': 'Virginia',
#   'country': 'USA'},
#  {'name': 'Freddie Gillespie',
#   'team': 'Toronto Raptors',
#   'number': None,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 111,
#   'school': 'Baylor',
#   'country': 'USA'},
#  {'name': 'Rudy Gobert',
#   'team': 'Utah Jazz',
#   'number': 27,
#   'position': 'C',
#   'height': 216.4,
#   'weight': 117,
#   'school': 'Cholet',
#   'country': 'France'},
#  {'name': 'Brandon Goodwin',
#   'team': 'Atlanta Hawks',
#   'number': 0,
#   'position': 'G',
#   'height': 182.9,
#   'weight': 81,
#   'school': 'Florida Gulf Coast',
#   'country': 'USA'},
#  {'name': 'Aaron Gordon',
#   'team': 'Denver Nuggets',
#   'number': 50,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 106,
#   'school': 'Arizona',
#   'country': 'USA'},
#  {'name': 'Eric Gordon',
#   'team': 'Houston Rockets',
#   'number': 10,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 97,
#   'school': 'Indiana',
#   'country': 'USA'},
#  {'name': "Devonte' Graham",
#   'team': 'Charlotte Hornets',
#   'number': 4,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 88,
#   'school': 'Kansas',
#   'country': 'USA'},
#  {'name': 'Jerami Grant',
#   'team': 'Detroit Pistons',
#   'number': 9,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 95,
#   'school': 'Syracuse',
#   'country': 'USA'},
#  {'name': 'Danny Green',
#   'team': 'Philadelphia 76ers',
#   'number': 14,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 97,
#   'school': 'North Carolina',
#   'country': 'USA'},
#  {'name': 'Draymond Green',
#   'team': 'Golden State Wariors',
#   'number': 23,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 104,
#   'school': 'Michigan State',
#   'country': 'USA'},
#  {'name': 'JaMychal Green',
#   'team': 'Denver Nuggets',
#   'number': 0,
#   'position': 'F-C',
#   'height': 207.3,
#   'weight': 102,
#   'school': 'Alabama',
#   'country': 'USA'},
#  {'name': 'Javonte Green',
#   'team': 'Chicago Bulls',
#   'number': 11,
#   'position': 'G-F',
#   'height': 195.1,
#   'weight': 92,
#   'school': 'Radford',
#   'country': 'USA'},
#  {'name': 'Jeff Green',
#   'team': 'Brooklyn Nets',
#   'number': 8,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 106,
#   'school': 'Georgetown',
#   'country': 'USA'},
#  {'name': 'Josh Green',
#   'team': 'Dallas Mavericks',
#   'number': 8,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 90,
#   'school': 'Arizona',
#   'country': 'Australia'},
#  {'name': 'Blake Griffin',
#   'team': 'Brooklyn Nets',
#   'number': 2,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 113,
#   'school': 'Oklahoma',
#   'country': 'USA'},
#  {'name': 'Kyle Guy',
#   'team': 'Sacramento Kings',
#   'number': 7,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 75,
#   'school': 'Virginia',
#   'country': 'USA'},
#  {'name': 'Rui Hachimura',
#   'team': 'Washington Wizards',
#   'number': 8,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 104,
#   'school': 'Gonzaga',
#   'country': 'Japan'},
#  {'name': 'Ashton Hagans',
#   'team': None,
#   'number': None,
#   'position': 'G-F',
#   'height': 192.0,
#   'weight': 86,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  {'name': 'Tyrese Haliburton',
#   'team': 'Sacramento Kings',
#   'number': 0,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 83,
#   'school': 'Iowa State',
#   'country': 'USA'},
#  {'name': 'Donta Hall',
#   'team': None,
#   'number': None,
#   'position': 'C',
#   'height': 185.9,
#   'weight': 104,
#   'school': 'Alabama',
#   'country': 'USA'},
#  {'name': 'Josh Hall',
#   'team': 'Oklahoma Thunder',
#   'number': 15,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 86,
#   'school': 'Moravian Prep (NC)',
#   'country': 'USA'},
#  {'name': 'R.J. Hampton',
#   'team': 'Orlando Magic',
#   'number': 13,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 79,
#   'school': 'New Zealand Breakers',
#   'country': 'USA'},
#  {'name': 'Tim Hardaway Jr.',
#   'team': 'Dallas Mavericks',
#   'number': 11,
#   'position': 'G-F',
#   'height': 198.1,
#   'weight': 92,
#   'school': 'Michigan',
#   'country': 'USA'},
#  {'name': 'James Harden',
#   'team': 'Brooklyn Nets',
#   'number': 13,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 99,
#   'school': 'Arizona State',
#   'country': 'USA'},
#  {'name': 'Maurice Harkless',
#   'team': 'Sacramento Kings',
#   'number': 8,
#   'position': 'F-G',
#   'height': 204.2,
#   'weight': 99,
#   'school': "St. John's",
#   'country': 'USA'},
#  {'name': 'Jared Harper',
#   'team': 'New York Knicks',
#   'number': 0,
#   'position': 'G',
#   'height': 155.4,
#   'weight': 79,
#   'school': 'Auburn',
#   'country': 'USA'},
#  {'name': 'Montrezl Harrell',
#   'team': 'Los Angeles Lackers',
#   'number': 15,
#   'position': 'F-C',
#   'height': 204.2,
#   'weight': 108,
#   'school': 'Louisville',
#   'country': 'USA'},
#  {'name': 'Gary Harris',
#   'team': 'Orlando Magic',
#   'number': 14,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 95,
#   'school': 'Michigan State',
#   'country': 'USA'},
#  {'name': 'Jalen Harris',
#   'team': None,
#   'number': None,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 88,
#   'school': 'Nevada',
#   'country': 'USA'},
#  {'name': 'Joe Harris',
#   'team': 'Brooklyn Nets',
#   'number': 12,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 99,
#   'school': 'Virginia',
#   'country': 'USA'},
#  {'name': 'Tobias Harris',
#   'team': 'Philadelphia 76ers',
#   'number': 12,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 102,
#   'school': 'Tennessee',
#   'country': 'USA'},
#  {'name': 'Shaquille Harrison',
#   'team': 'Denver Nuggets',
#   'number': 3,
#   'position': 'G',
#   'height': 204.2,
#   'weight': 86,
#   'school': 'Tulsa',
#   'country': 'USA'},
#  {'name': 'Josh Hart',
#   'team': 'New Orleans Pelicans',
#   'number': 3,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 97,
#   'school': 'Villanova',
#   'country': 'USA'},
#  {'name': 'Isaiah Hartenstein',
#   'team': 'Cleveland Cavaliers',
#   'number': 55,
#   'position': 'C-F',
#   'height': 213.4,
#   'weight': 113,
#   'school': 'Zalgiris',
#   'country': 'Germany'},
#  {'name': 'Udonis Haslem',
#   'team': 'Miami Heat',
#   'number': 40,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 106,
#   'school': 'Florida',
#   'country': 'USA'},
#  {'name': 'Jaxson Hayes',
#   'team': 'New Orleans Pelicans',
#   'number': 10,
#   'position': 'C-F',
#   'height': 186.2,
#   'weight': 99,
#   'school': 'Texas-Austin',
#   'country': 'USA'},
#  {'name': 'Killian Hayes',
#   'team': 'Detroit Pistons',
#   'number': 7,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 88,
#   'school': 'Ratiopharm Ulm',
#   'country': 'France'},
#  {'name': 'Gordon Hayward',
#   'team': 'Charlotte Hornets',
#   'number': 20,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 102,
#   'school': 'Butler',
#   'country': 'USA'},
#  {'name': 'Juancho Hernangomez',
#   'team': 'Minnesota Timberwolves',
#   'number': 41,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 97,
#   'school': 'Estudiantes',
#   'country': 'Spain'},
#  {'name': 'Willy Hernangomez',
#   'team': 'New Orleans Pelicans',
#   'number': 9,
#   'position': 'C-F',
#   'height': 186.2,
#   'weight': 113,
#   'school': 'Cajasol Sevilla',
#   'country': 'Spain'},
#  {'name': 'Tyler Herro',
#   'team': 'Miami Heat',
#   'number': 14,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 88,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  {'name': 'Buddy Hield',
#   'team': 'Sacramento Kings',
#   'number': 24,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 99,
#   'school': 'Oklahoma',
#   'country': 'Bahamas'},
#  {'name': 'George Hill',
#   'team': 'Philadelphia 76ers',
#   'number': 33,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 85,
#   'school': 'Indiana-Purdue Indianapolis',
#   'country': 'USA'},
#  {'name': 'Solomon Hill',
#   'team': 'Atlanta Hawks',
#   'number': 18,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 102,
#   'school': 'Arizona',
#   'country': 'USA'},
#  {'name': 'Nate Hinton',
#   'team': 'Dallas Mavericks',
#   'number': 14,
#   'position': 'G-F',
#   'height': 198.1,
#   'weight': 95,
#   'school': 'Houston',
#   'country': 'USA'},
#  {'name': 'Jaylen Hoard',
#   'team': 'Oklahoma Thunder',
#   'number': 8,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 97,
#   'school': 'Wake Forest',
#   'country': 'France'},
#  {'name': 'Aaron Holiday',
#   'team': 'Indiana Pacers',
#   'number': 3,
#   'position': 'G',
#   'height': 182.9,
#   'weight': 83,
#   'school': 'UCLA',
#   'country': 'USA'},
#  {'name': 'Jrue Holiday',
#   'team': 'Milwaukee Bucks',
#   'number': 21,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 92,
#   'school': 'UCLA',
#   'country': 'USA'},
#  {'name': 'Justin Holiday',
#   'team': 'Indiana Pacers',
#   'number': 8,
#   'position': 'F-G',
#   'height': 201.2,
#   'weight': 81,
#   'school': 'Washington',
#   'country': 'USA'},
#  {'name': 'Rondae Hollis-Jefferson',
#   'team': 'Portland Trail Blazers',
#   'number': 2,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 98,
#   'school': 'Arizona',
#   'country': 'USA'},
#  {'name': 'Richaun Holmes',
#   'team': 'Sacramento Kings',
#   'number': 22,
#   'position': 'F',
#   'height': 185.9,
#   'weight': 106,
#   'school': 'Bowling Green',
#   'country': 'USA'},
#  {'name': 'Caleb Homesley',
#   'team': 'Washington Wizards',
#   'number': None,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 92,
#   'school': 'Liberty',
#   'country': 'USA'},
#  {'name': 'Rodney Hood',
#   'team': 'Toronto Raptors',
#   'number': 32,
#   'position': 'G-F',
#   'height': 207.3,
#   'weight': 94,
#   'school': 'Duke',
#   'country': 'USA'},
#  {'name': 'Al Horford',
#   'team': 'Boston Celtics',
#   'number': 42,
#   'position': 'C-F',
#   'height': 210.3,
#   'weight': 108,
#   'school': 'Florida',
#   'country': 'Dominican Republic'},
#  {'name': 'Talen Horton-Tucker',
#   'team': 'Los Angeles Lackers',
#   'number': 5,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 106,
#   'school': 'Iowa State',
#   'country': 'USA'},
#  {'name': 'Danuel House Jr.',
#   'team': 'Houston Rockets',
#   'number': 4,
#   'position': 'F-G',
#   'height': 201.2,
#   'weight': 99,
#   'school': 'Texas A&M',
#   'country': 'USA'},
#  {'name': 'Dwight Howard',
#   'team': 'Philadelphia 76ers',
#   'number': 39,
#   'position': 'C-F',
#   'height': 185.9,
#   'weight': 120,
#   'school': 'SW Atlanta Christian Academy (GA)',
#   'country': 'USA'},
#  {'name': 'Markus Howard',
#   'team': 'Denver Nuggets',
#   'number': 0,
#   'position': 'G',
#   'height': 155.4,
#   'weight': 79,
#   'school': 'Marquette',
#   'country': 'USA'},
#  {'name': 'Kevin Huerter',
#   'team': 'Atlanta Hawks',
#   'number': 3,
#   'position': 'G-F',
#   'height': 204.2,
#   'weight': 86,
#   'school': 'Maryland',
#   'country': 'USA'},
#  {'name': 'Elijah Hughes',
#   'team': 'Utah Jazz',
#   'number': 33,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 97,
#   'school': 'Syracuse',
#   'country': 'USA'},
#  {'name': "De'Andre Hunter",
#   'team': 'Atlanta Hawks',
#   'number': 12,
#   'position': 'F-G',
#   'height': 207.3,
#   'weight': 102,
#   'school': 'Virginia',
#   'country': 'USA'},
#  {'name': 'Chandler Hutchison',
#   'team': 'Washington Wizards',
#   'number': 1,
#   'position': 'F-G',
#   'height': 201.2,
#   'weight': 95,
#   'school': 'Boise State',
#   'country': 'USA'},
#  {'name': 'Serge Ibaka',
#   'team': 'LA Clippers',
#   'number': 9,
#   'position': 'F',
#   'height': 185.9,
#   'weight': 106,
#   'school': 'Ricoh Manresa',
#   'country': 'Republic of the Congo'},
#  {'name': 'Andre Iguodala',
#   'team': 'Miami Heat',
#   'number': 28,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 97,
#   'school': 'Arizona',
#   'country': 'USA'},
#  {'name': 'Ersan Ilyasova',
#   'team': 'Utah Jazz',
#   'number': 77,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 106,
#   'school': 'FC Barcelona',
#   'country': 'Turkey'},
#  {'name': 'Joe Ingles',
#   'team': 'Utah Jazz',
#   'number': 2,
#   'position': 'F-G',
#   'height': 207.3,
#   'weight': 99,
#   'school': 'Maccabi Tel Aviv',
#   'country': 'Australia'},
#  {'name': 'Brandon Ingram',
#   'team': 'New Orleans Pelicans',
#   'number': 14,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 86,
#   'school': 'Duke',
#   'country': 'USA'},
#  {'name': 'Kyrie Irving',
#   'team': 'Brooklyn Nets',
#   'number': 11,
#   'position': 'G',
#   'height': 189.0,
#   'weight': 88,
#   'school': 'Duke',
#   'country': 'Australia'},
#  {'name': 'Jonathan Isaac',
#   'team': 'Orlando Magic',
#   'number': 1,
#   'position': 'F',
#   'height': 186.2,
#   'weight': 104,
#   'school': 'Florida State',
#   'country': 'USA'},
#  {'name': 'Wes Iwundu',
#   'team': 'New Orleans Pelicans',
#   'number': 4,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 88,
#   'school': 'Kansas State',
#   'country': 'USA'},
#  {'name': 'Frank Jackson',
#   'team': 'Detroit Pistons',
#   'number': 5,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 92,
#   'school': 'Duke',
#   'country': 'USA'},
#  {'name': 'Josh Jackson',
#   'team': 'Detroit Pistons',
#   'number': 20,
#   'position': 'G-F',
#   'height': 207.3,
#   'weight': 93,
#   'school': 'Kansas',
#   'country': 'USA'},
#  {'name': 'Justin Jackson',
#   'team': 'Milwaukee Bucks',
#   'number': 44,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 99,
#   'school': 'North Carolina',
#   'country': 'USA'},
#  {'name': 'Reggie Jackson',
#   'team': 'LA Clippers',
#   'number': 1,
#   'position': 'G',
#   'height': 189.0,
#   'weight': 94,
#   'school': 'Boston College',
#   'country': 'USA'},
#  {'name': 'Jaren Jackson Jr.',
#   'team': 'Memphis Grizzlies',
#   'number': 13,
#   'position': 'F-C',
#   'height': 186.2,
#   'weight': 109,
#   'school': 'Michigan State',
#   'country': 'USA'},
#  {'name': 'Justin James',
#   'team': 'Sacramento Kings',
#   'number': 10,
#   'position': 'G-F',
#   'height': 204.2,
#   'weight': 86,
#   'school': 'Wyoming',
#   'country': 'USA'},
#  {'name': 'LeBron James',
#   'team': 'Los Angeles Lackers',
#   'number': 6,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 113,
#   'school': 'St. Vincent-St. Mary HS (OH)',
#   'country': 'USA'},
#  {'name': 'Mike James',
#   'team': 'Brooklyn Nets',
#   'number': 55,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 79,
#   'school': 'Lamar',
#   'country': 'USA'},
#  {'name': 'DaQuan Jeffries',
#   'team': 'San Antonio Spurs',
#   'number': 55,
#   'position': 'G-F',
#   'height': 198.1,
#   'weight': 104,
#   'school': 'Tulsa',
#   'country': 'USA'},
#  {'name': 'Ty Jerome',
#   'team': 'Oklahoma Thunder',
#   'number': 16,
#   'position': 'G-F',
#   'height': 198.1,
#   'weight': 88,
#   'school': 'Virginia',
#   'country': 'USA'},
#  {'name': 'Isaiah Joe',
#   'team': 'Philadelphia 76ers',
#   'number': 7,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 74,
#   'school': 'Arkansas',
#   'country': 'USA'},
#  {'name': 'Alize Johnson',
#   'team': 'Brooklyn Nets',
#   'number': 24,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 96,
#   'school': 'Missouri State',
#   'country': 'USA'},
#  {'name': 'Cameron Johnson',
#   'team': 'Phoenix Suns',
#   'number': 23,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 95,
#   'school': 'North Carolina',
#   'country': 'USA'},
#  {'name': 'James Johnson',
#   'team': 'New Orleans Pelicans',
#   'number': 16,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 108,
#   'school': 'Wake Forest',
#   'country': 'USA'},
#  {'name': 'Keldon Johnson',
#   'team': 'San Antonio Spurs',
#   'number': 3,
#   'position': 'F-G',
#   'height': 198.1,
#   'weight': 99,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  {'name': 'Stanley Johnson',
#   'team': 'Toronto Raptors',
#   'number': 5,
#   'position': 'F-G',
#   'height': 201.2,
#   'weight': 109,
#   'school': 'Arizona',
#   'country': 'USA'},
#  {'name': 'Tyler Johnson',
#   'team': 'Brooklyn Nets',
#   'number': 10,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 84,
#   'school': 'Fresno State',
#   'country': 'USA'},
#  {'name': 'Nikola Jokic',
#   'team': 'Denver Nuggets',
#   'number': 15,
#   'position': 'C',
#   'height': 186.2,
#   'weight': 128,
#   'school': 'Mega Basket',
#   'country': 'Serbia'},
#  {'name': 'Damian Jones',
#   'team': 'Sacramento Kings',
#   'number': 15,
#   'position': 'C',
#   'height': 186.2,
#   'weight': 111,
#   'school': 'Vanderbilt',
#   'country': 'USA'},
#  {'name': 'Mason Jones',
#   'team': None,
#   'number': None,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 90,
#   'school': 'Arkansas',
#   'country': 'USA'},
#  {'name': 'Tre Jones',
#   'team': 'San Antonio Spurs',
#   'number': 33,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 83,
#   'school': 'Duke',
#   'country': 'USA'},
#  {'name': 'Tyus Jones',
#   'team': 'Memphis Grizzlies',
#   'number': 21,
#   'position': 'G',
#   'height': 182.9,
#   'weight': 88,
#   'school': 'Duke',
#   'country': 'USA'},
#  {'name': 'Derrick Jones Jr.',
#   'team': 'Portland Trail Blazers',
#   'number': 5,
#   'position': 'F',
#   'height': 198.1,
#   'weight': 95,
#   'school': 'UNLV',
#   'country': 'USA'},
#  {'name': 'DeAndre Jordan',
#   'team': 'Brooklyn Nets',
#   'number': 6,
#   'position': 'C',
#   'height': 186.2,
#   'weight': 120,
#   'school': 'Texas A&M',
#   'country': 'USA'},
#  {'name': 'Cory Joseph',
#   'team': 'Detroit Pistons',
#   'number': 18,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 90,
#   'school': 'Texas-Austin',
#   'country': 'Canada'},
#  {'name': 'Mfiondu Kabengele',
#   'team': 'Cleveland Cavaliers',
#   'number': 27,
#   'position': 'F-C',
#   'height': 210.3,
#   'weight': 113,
#   'school': 'Florida State',
#   'country': 'Canada'},
#  {'name': 'Frank Kaminsky',
#   'team': 'Phoenix Suns',
#   'number': 8,
#   'position': 'F-C',
#   'height': 213.4,
#   'weight': 108,
#   'school': 'Wisconsin',
#   'country': 'USA'},
#  {'name': 'Enes Kanter',
#   'team': 'Portland Trail Blazers',
#   'number': 11,
#   'position': 'C',
#   'height': 185.9,
#   'weight': 113,
# ...
#   'country': 'USA'},
#  {'name': 'Landry Shamet',
#   'team': 'Brooklyn Nets',
#   'number': 20,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 86,
#   'school': 'Wichita State',
#   'country': 'USA'},
#  {'name': 'Iman Shumpert',
#   'team': None,
#   'number': None,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 96,
#   'school': 'Georgia Tech',
#   'country': 'USA'},
#  {'name': 'Pascal Siakam',
#   'team': 'Toronto Raptors',
#   'number': 43,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 104,
#   'school': 'New Mexico State',
#   'country': 'Cameroon'},
#  {'name': 'Chris Silva',
#   'team': None,
#   'number': None,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 106,
#   'school': 'South Carolina',
#   'country': 'Gabon'},
#  {'name': 'Ben Simmons',
#   'team': 'Philadelphia 76ers',
#   'number': 25,
#   'position': 'G-F',
#   'height': 186.2,
#   'weight': 108,
#   'school': 'Louisiana State',
#   'country': 'Australia'},
#  {'name': 'Anfernee Simons',
#   'team': 'Portland Trail Blazers',
#   'number': 1,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 82,
#   'school': 'Edgewater HS (FL)',
#   'country': 'USA'},
#  {'name': 'Deividas Sirvydis',
#   'team': 'Detroit Pistons',
#   'number': 91,
#   'position': 'F-G',
#   'height': 207.3,
#   'weight': 86,
#   'school': 'Lietuvos rytas Vilnius',
#   'country': 'Lithuania'},
#  {'name': 'Alen Smailagic',
#   'team': 'Golden State Wariors',
#   'number': 6,
#   'position': 'F',
#   'height': 185.9,
#   'weight': 97,
#   'school': 'Beko',
#   'country': 'Serbia'},
#  {'name': 'Marcus Smart',
#   'team': 'Boston Celtics',
#   'number': 36,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 99,
#   'school': 'Oklahoma State',
#   'country': 'USA'},
#  {'name': 'Ish Smith',
#   'team': 'Washington Wizards',
#   'number': 14,
#   'position': 'G',
#   'height': 182.9,
#   'weight': 79,
#   'school': 'Wake Forest',
#   'country': 'USA'},
#  {'name': 'Jalen Smith',
#   'team': 'Phoenix Suns',
#   'number': 10,
#   'position': 'F-C',
#   'height': 185.9,
#   'weight': 97,
#   'school': 'Maryland',
#   'country': 'USA'},
#  {'name': 'Dennis Smith Jr.',
#   'team': 'Detroit Pistons',
#   'number': 0,
#   'position': 'G',
#   'height': 189.0,
#   'weight': 92,
#   'school': 'North Carolina State',
#   'country': 'USA'},
#  {'name': 'Tony Snell',
#   'team': 'Atlanta Hawks',
#   'number': 19,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 96,
#   'school': 'New Mexico',
#   'country': 'USA'},
#  {'name': 'Ray Spalding',
#   'team': None,
#   'number': None,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 102,
#   'school': 'Louisville',
#   'country': 'USA'},
#  {'name': 'Cassius Stanley',
#   'team': 'Indiana Pacers',
#   'number': 2,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 86,
#   'school': 'Duke',
#   'country': 'USA'},
#  {'name': 'Lamar Stevens',
#   'team': 'Cleveland Cavaliers',
#   'number': 8,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 104,
#   'school': 'Penn State',
#   'country': 'USA'},
#  {'name': 'Isaiah Stewart',
#   'team': 'Detroit Pistons',
#   'number': 28,
#   'position': 'F-C',
#   'height': 207.3,
#   'weight': 113,
#   'school': 'Washington',
#   'country': 'USA'},
#  {'name': 'Max Strus',
#   'team': 'Miami Heat',
#   'number': 31,
#   'position': 'G-F',
#   'height': 198.1,
#   'weight': 97,
#   'school': 'DePaul',
#   'country': 'USA'},
#  {'name': 'Edmond Sumner',
#   'team': 'Indiana Pacers',
#   'number': 5,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 88,
#   'school': 'Xavier',
#   'country': 'USA'},
#  {'name': "Jae'Sean Tate",
#   'team': 'Houston Rockets',
#   'number': 8,
#   'position': 'F',
#   'height': 195.1,
#   'weight': 104,
#   'school': 'Ohio State',
#   'country': 'USA'},
#  {'name': 'Jayson Tatum',
#   'team': 'Boston Celtics',
#   'number': 0,
#   'position': 'F-G',
#   'height': 207.3,
#   'weight': 95,
#   'school': 'Duke',
#   'country': 'USA'},
#  {'name': 'Jeff Teague',
#   'team': 'Milwaukee Bucks',
#   'number': 5,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 88,
#   'school': 'Wake Forest',
#   'country': 'USA'},
#  {'name': 'Garrett Temple',
#   'team': 'Chicago Bulls',
#   'number': 17,
#   'position': 'G-F',
#   'height': 198.1,
#   'weight': 88,
#   'school': 'Louisiana State',
#   'country': 'USA'},
#  {'name': 'Tyrell Terry',
#   'team': 'Dallas Mavericks',
#   'number': 1,
#   'position': 'G',
#   'height': 189.0,
#   'weight': 72,
#   'school': 'Stanford',
#   'country': 'USA'},
#  {'name': 'Daniel Theis',
#   'team': 'Chicago Bulls',
#   'number': 27,
#   'position': 'F-C',
#   'height': 207.3,
#   'weight': 111,
#   'school': 'Brose Bamberg',
#   'country': 'Germany'},
#  {'name': 'Brodric Thomas',
#   'team': 'Cleveland Cavaliers',
#   'number': 33,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 83,
#   'school': 'Truman State',
#   'country': 'USA'},
#  {'name': 'Isaiah Thomas',
#   'team': None,
#   'number': None,
#   'position': 'G',
#   'height': 179.8,
#   'weight': 83,
#   'school': 'Washington',
#   'country': 'USA'},
#  {'name': 'Khyri Thomas',
#   'team': 'Houston Rockets',
#   'number': 13,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 95,
#   'school': 'Creighton',
#   'country': 'USA'},
#  {'name': 'Matt Thomas',
#   'team': 'Utah Jazz',
#   'number': 21,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 86,
#   'school': 'Iowa State',
#   'country': 'USA'},
#  {'name': 'Klay Thompson',
#   'team': 'Golden State Wariors',
#   'number': 11,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 97,
#   'school': 'Washington State',
#   'country': 'USA'},
#  {'name': 'Tristan Thompson',
#   'team': 'Boston Celtics',
#   'number': 13,
#   'position': 'C-F',
#   'height': 210.3,
#   'weight': 115,
#   'school': 'Texas-Austin',
#   'country': 'Canada'},
#  {'name': 'Sindarius Thornwell',
#   'team': 'Orlando Magic',
#   'number': 15,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 97,
#   'school': 'South Carolina',
#   'country': 'USA'},
#  {'name': 'Matisse Thybulle',
#   'team': 'Philadelphia 76ers',
#   'number': 22,
#   'position': 'G-F',
#   'height': 198.1,
#   'weight': 91,
#   'school': 'Washington',
#   'country': 'USA'},
#  {'name': 'Killian Tillie',
#   'team': 'Memphis Grizzlies',
#   'number': 35,
#   'position': 'F-C',
#   'height': 210.3,
#   'weight': 99,
#   'school': 'Gonzaga',
#   'country': 'France'},
#  {'name': 'Xavier Tillman',
#   'team': 'Memphis Grizzlies',
#   'number': 2,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 111,
#   'school': 'Michigan State',
#   'country': 'USA'},
#  {'name': 'Anthony Tolliver',
#   'team': 'Philadelphia 76ers',
#   'number': 43,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 108,
#   'school': 'Creighton',
#   'country': 'USA'},
#  {'name': 'Obi Toppin',
#   'team': 'New York Knicks',
#   'number': 1,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 99,
#   'school': 'Dayton',
#   'country': 'USA'},
#  {'name': 'Juan Toscano-Anderson',
#   'team': 'Golden State Wariors',
#   'number': 95,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 94,
#   'school': 'Marquette',
#   'country': 'USA'},
#  {'name': 'Axel Toupane',
#   'team': 'Milwaukee Bucks',
#   'number': 66,
#   'position': 'G-F',
#   'height': 204.2,
#   'weight': 95,
#   'school': 'Strasbourg IG',
#   'country': 'France'},
#  {'name': 'Karl-Anthony Towns',
#   'team': 'Minnesota Timberwolves',
#   'number': 32,
#   'position': 'C-F',
#   'height': 186.2,
#   'weight': 112,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  {'name': 'Gary Trent Jr.',
#   'team': 'Toronto Raptors',
#   'number': 33,
#   'position': 'G-F',
#   'height': 198.1,
#   'weight': 94,
#   'school': 'Duke',
#   'country': 'USA'},
#  {'name': 'P.J. Tucker',
#   'team': 'Milwaukee Bucks',
#   'number': 17,
#   'position': 'F',
#   'height': 198.1,
#   'weight': 111,
#   'school': 'Texas-Austin',
#   'country': 'USA'},
#  {'name': 'Rayjon Tucker',
#   'team': 'Philadelphia 76ers',
#   'number': 9,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 94,
#   'school': 'Arkansas-Little Rock',
#   'country': 'USA'},
#  {'name': 'Myles Turner',
#   'team': 'Indiana Pacers',
#   'number': 33,
#   'position': 'C-F',
#   'height': 186.2,
#   'weight': 113,
#   'school': 'Texas-Austin',
#   'country': 'USA'},
#  {'name': 'Jonas Valanciunas',
#   'team': 'Memphis Grizzlies',
#   'number': 17,
#   'position': 'C',
#   'height': 186.2,
#   'weight': 120,
#   'school': 'Lietuvos rytas Vilnius',
#   'country': 'Lithuania'},
#  {'name': 'Denzel Valentine',
#   'team': 'Chicago Bulls',
#   'number': 45,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 99,
#   'school': 'Michigan State',
#   'country': 'USA'},
#  {'name': 'Fred VanVleet',
#   'team': 'Toronto Raptors',
#   'number': 23,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 89,
#   'school': 'Wichita State',
#   'country': 'USA'},
#  {'name': 'Jarred Vanderbilt',
#   'team': 'Minnesota Timberwolves',
#   'number': 8,
#   'position': 'F',
#   'height': 210.3,
#   'weight': 97,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  {'name': 'Anderson Varejao',
#   'team': None,
#   'number': None,
#   'position': 'F',
#   'height': 186.2,
#   'weight': 117,
#   'school': ' ',
#   'country': 'Brazil'},
#  {'name': 'Devin Vassell',
#   'team': 'San Antonio Spurs',
#   'number': 24,
#   'position': 'G-F',
#   'height': 198.1,
#   'weight': 90,
#   'school': 'Florida State',
#   'country': 'USA'},
#  {'name': 'Luca Vildoza',
#   'team': 'New York Knicks',
#   'number': None,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 86,
#   'school': 'Baskonia',
#   'country': ''},
#  {'name': 'Gabe Vincent',
#   'team': 'Miami Heat',
#   'number': 2,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 90,
#   'school': 'California-Santa Barbara',
#   'country': 'USA'},
#  {'name': 'Noah Vonleh',
#   'team': None,
#   'number': None,
#   'position': 'F',
#   'height': 185.9,
#   'weight': 116,
#   'school': 'Indiana',
#   'country': 'USA'},
#  {'name': 'Nikola Vucevic',
#   'team': 'Chicago Bulls',
#   'number': 9,
#   'position': 'C',
#   'height': 186.2,
#   'weight': 117,
#   'school': 'Southern California',
#   'country': 'Montenegro'},
#  {'name': 'Dean Wade',
#   'team': 'Cleveland Cavaliers',
#   'number': 32,
#   'position': 'F-C',
#   'height': 210.3,
#   'weight': 103,
#   'school': 'Kansas State',
#   'country': 'USA'},
#  {'name': 'Moritz Wagner',
#   'team': 'Orlando Magic',
#   'number': 21,
#   'position': 'F-C',
#   'height': 186.2,
#   'weight': 111,
#   'school': 'Michigan',
#   'country': 'Germany'},
#  {'name': 'Kemba Walker',
#   'team': 'Oklahoma Thunder',
#   'number': 8,
#   'position': 'G',
#   'height': 182.9,
#   'weight': 83,
#   'school': 'Connecticut',
#   'country': 'USA'},
#  {'name': 'Lonnie Walker IV',
#   'team': 'San Antonio Spurs',
#   'number': 1,
#   'position': 'G-F',
#   'height': 195.1,
#   'weight': 92,
#   'school': 'Miami',
#   'country': 'USA'},
#  {'name': 'John Wall',
#   'team': 'Houston Rockets',
#   'number': 1,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 95,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  {'name': 'Brad Wanamaker',
#   'team': 'Charlotte Hornets',
#   'number': 9,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 95,
#   'school': 'Pittsburgh',
#   'country': 'USA'},
#  {'name': 'T.J. Warren',
#   'team': 'Indiana Pacers',
#   'number': 1,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 99,
#   'school': 'North Carolina State',
#   'country': 'USA'},
#  {'name': 'P.J. Washington',
#   'team': 'Charlotte Hornets',
#   'number': 25,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 104,
#   'school': 'Kentucky',
#   'country': 'USA'},
#  {'name': 'Yuta Watanabe',
#   'team': 'Toronto Raptors',
#   'number': 18,
#   'position': 'G-F',
#   'height': 210.3,
#   'weight': 97,
#   'school': 'George Washington',
#   'country': 'Japan'},
#  {'name': 'Tremont Waters',
#   'team': 'Boston Celtics',
#   'number': 51,
#   'position': 'G',
#   'height': 155.4,
#   'weight': 79,
#   'school': 'Louisiana State',
#   'country': 'USA'},
#  {'name': 'Paul Watson',
#   'team': 'Toronto Raptors',
#   'number': 1,
#   'position': 'G',
#   'height': 201.2,
#   'weight': 95,
#   'school': 'Fresno State',
#   'country': 'USA'},
#  {'name': 'Quinndary Weatherspoon',
#   'team': 'San Antonio Spurs',
#   'number': 15,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 92,
#   'school': 'Mississippi State',
#   'country': 'USA'},
#  {'name': 'Russell Westbrook',
#   'team': 'Washington Wizards',
#   'number': 4,
#   'position': 'G',
#   'height': 192.0,
#   'weight': 90,
#   'school': 'UCLA',
#   'country': 'USA'},
#  {'name': 'Coby White',
#   'team': 'Chicago Bulls',
#   'number': 0,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 88,
#   'school': 'North Carolina',
#   'country': 'USA'},
#  {'name': 'Derrick White',
#   'team': 'San Antonio Spurs',
#   'number': 4,
#   'position': 'G',
#   'height': 195.1,
#   'weight': 86,
#   'school': 'Colorado',
#   'country': 'USA'},
#  {'name': 'Hassan Whiteside',
#   'team': 'Sacramento Kings',
#   'number': 20,
#   'position': 'C',
#   'height': 213.4,
#   'weight': 120,
#   'school': 'Marshall',
#   'country': 'USA'},
#  {'name': 'Greg Whittington',
#   'team': None,
#   'number': None,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 95,
#   'school': 'Georgetown',
#   'country': 'USA'},
#  {'name': 'Andrew Wiggins',
#   'team': 'Golden State Wariors',
#   'number': 22,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 89,
#   'school': 'Kansas',
#   'country': 'Canada'},
#  {'name': 'Grant Williams',
#   'team': 'Boston Celtics',
#   'number': 12,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 107,
#   'school': 'Tennessee',
#   'country': 'USA'},
#  {'name': 'Kenrich Williams',
#   'team': 'Oklahoma Thunder',
#   'number': 34,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 95,
#   'school': 'TCU',
#   'country': 'USA'},
#  {'name': 'Lou Williams',
#   'team': 'Atlanta Hawks',
#   'number': 6,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 79,
#   'school': 'South Gwinnett HS (GA)',
#   'country': 'USA'},
#  {'name': 'Patrick Williams',
#   'team': 'Chicago Bulls',
#   'number': 44,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 97,
#   'school': 'Florida State',
#   'country': 'USA'},
#  {'name': 'Robert Williams III',
#   'team': 'Boston Celtics',
#   'number': 44,
#   'position': 'C-F',
#   'height': 207.3,
#   'weight': 107,
#   'school': 'Texas A&M',
#   'country': 'USA'},
#  {'name': 'Zion Williamson',
#   'team': 'New Orleans Pelicans',
#   'number': 1,
#   'position': 'F',
#   'height': 204.2,
#   'weight': 128,
#   'school': 'Duke',
#   'country': 'USA'},
#  {'name': 'D.J. Wilson',
#   'team': 'Houston Rockets',
#   'number': 0,
#   'position': 'F',
#   'height': 185.9,
#   'weight': 104,
#   'school': 'Michigan',
#   'country': 'USA'},
#  {'name': 'Dylan Windler',
#   'team': 'Cleveland Cavaliers',
#   'number': 9,
#   'position': 'G-F',
#   'height': 201.2,
#   'weight': 88,
#   'school': 'Belmont',
#   'country': 'USA'},
#  {'name': 'Justise Winslow',
#   'team': 'Memphis Grizzlies',
#   'number': 7,
#   'position': 'F-G',
#   'height': 201.2,
#   'weight': 100,
#   'school': 'Duke',
#   'country': 'USA'},
#  {'name': 'Cassius Winston',
#   'team': 'Washington Wizards',
#   'number': 5,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 83,
#   'school': 'Michigan State',
#   'country': 'USA'},
#  {'name': 'James Wiseman',
#   'team': 'Golden State Wariors',
#   'number': 33,
#   'position': 'C',
#   'height': 213.4,
#   'weight': 108,
#   'school': 'Memphis',
#   'country': 'USA'},
#  {'name': 'Christian Wood',
#   'team': 'Houston Rockets',
#   'number': 35,
#   'position': 'F',
#   'height': 185.9,
#   'weight': 97,
#   'school': 'UNLV',
#   'country': 'USA'},
#  {'name': 'Robert Woodard II',
#   'team': 'Sacramento Kings',
#   'number': 13,
#   'position': 'F',
#   'height': 201.2,
#   'weight': 106,
#   'school': 'Mississippi State',
#   'country': 'USA'},
#  {'name': 'Delon Wright',
#   'team': 'Sacramento Kings',
#   'number': 55,
#   'position': 'G',
#   'height': 198.1,
#   'weight': 83,
#   'school': 'Utah',
#   'country': 'USA'},
#  {'name': 'Thaddeus Young',
#   'team': 'Chicago Bulls',
#   'number': 21,
#   'position': 'F',
#   'height': 207.3,
#   'weight': 106,
#   'school': 'Georgia Tech',
#   'country': 'USA'},
#  {'name': 'Trae Young',
#   'team': 'Atlanta Hawks',
#   'number': 11,
#   'position': 'G',
#   'height': 185.9,
#   'weight': 81,
#   'school': 'Oklahoma',
#   'country': 'USA'},
#  {'name': 'Omer Yurtseven',
#   'team': 'Miami Heat',
#   'number': 77,
#   'position': 'C',
#   'height': 213.4,
#   'weight': 124,
#   'school': 'Georgetown',
#   'country': 'Uzbekistan'},
#  {'name': 'Cody Zeller',
#   'team': 'Charlotte Hornets',
#   'number': 40,
#   'position': 'F-C',
#   'height': 186.2,
#   'weight': 108,
#   'school': 'Indiana',
#   'country': 'USA'},
#  {'name': 'Ivica Zubac',
#   'team': 'LA Clippers',
#   'number': 40,
#   'position': 'C',
#   'height': 213.4,
#   'weight': 108,
#   'school': 'Mega Basket',
#   'country': 'Croatia'}]

# %%
dump_json = json.dumps(final_json)

with open (r"D:\Desktop\Sandbox\webscrap\NBAPlayers.json", "w") as f :
    f.write(dump_json)
